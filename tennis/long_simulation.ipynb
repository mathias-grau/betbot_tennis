# %%
# change dir to root
import os
import sys
print(os.getcwd())
if os.getcwd().split('/')[-1] == 'betbot_tennis':
    os.chdir(os.path.join(os.getcwd(), 'tennis'))
elif os.getcwd().split('/')[-1] == 'tennis':
    pass
else:
    raise ValueError('Not in root dir')
print(os.getcwd())
from utils.classes import TennisMatchDataset
import numpy as np
import pandas as pd
import json
import os 
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset, TensorDataset
import torch.optim as optim
from tqdm.notebook import tqdm
import torch 
from torch.utils.data import random_split
import utils.constants as c
import data.utils.constants as c2
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

MAX_PADDED = 20
# Strategy results : bet the proportion given by the kelly criterion on each match
INIT_AMOUNT = 100 # euros
GREEN = '\033[92m'
RED = '\033[91m'
RESET = '\033[0m'
# Out:
# /users/eleves-b/2021/mathias.grau/betbot_tennis/tennis
# /users/eleves-b/2021/mathias.grau/betbot_tennis/tennis

# %%
tournaments_2023 = [   
                    'past-french-open-2023-atp-singles',
                    'past-australian-open-2023-atp-singles',
                    'past-rome-2023-atp-singles',
                    'past-madrid-2023-atp-singles',
                    'past-monte-carlo-2023-atp-singles',
                    'past-lyon-2023-atp-singles',
                    'past-barcelona-2023-atp-singles',
                    'past-munich-2023-atp-singles',
                    'past-geneva-2023-atp-singles',
                    'past-estoril-2023-atp-singles',
                    'past-houston-2023-atp-singles',
                    'past-marrakech-2023-atp-singles', 
                    'past-doha-2023-atp-singles',
                    'past-dubai-2023-atp-singles',
                    'past-indian-wells-2023-atp-singles',
                    'past-miami-2023-atp-singles',
                    'past-acapulco-2023-atp-singles',
                    'past-rio-de-janeiro-2023-atp-singles',
                    'past-santiago-2023-atp-singles',
                    'past-auckland-2023-atp-singles',
                    'past-adelaide-2023-atp-singles',
                    'past-montpellier-2023-atp-singles',
                    'past-marseille-2023-atp-singles',
                    'past-cordoba-2023-atp-singles',
                    'past-dallas-2023-atp-singles',
                    'past-stuttgart-2023-atp-singles',
                    'past-hertogenbosch-2023-atp-singles',
                    'past-halle-2023-atp-singles',
                    'past-london-2023-atp-singles',
                    'past-mallorca-2023-atp-singles',
                    'past-eastbourne-2023-atp-singles',
                    'past-wimbledon-2023-atp-singles',
                    'past-hamburg-2023-atp-singles',
                    'past-bastad-2023-atp-singles',
                    'past-gstaad-2023-atp-singles', ###
                    'past-newport-2023-atp-singles',
                    'past-umag-2023-atp-singles',
                    'past-atlanta-2023-atp-singles',
                    'past-washington-2023-atp-singles',
                    'past-cincinnati-2023-atp-singles',
                    'past-winston-salem-2023-atp-singles',
                    'past-us-open-2023-atp-singles', ###
                    'past-chengdu-2023-atp-singles',
                    'past-zhuhai-2023-atp-singles', ###
                    'past-tokyo-2023-atp-singles',
                    'past-beijing-2023-atp-singles', ###
                    'past-shanghai-2023-atp-singles',
                    'past-stockholm-2023-atp-singles',
                    'past-antwerp-2023-atp-singles', ###
                    'past-vienna-2023-atp-singles',
                    'past-basel-2023-atp-singles',
                    'past-paris-2023-atp-singles',
                    'past-metz-2023-atp-singles',
                    'past-finals-turin-2023-atp-singles',
]
tournaments_ordered_2024 = [
                    ####
                    'past-brisbane-atp-singles',
                    'past-hong-kong-atp-singles',
                    'past-auckland-atp-singles',
                    'past-adelaide-atp-singles',
                    'past-australian-open-atp-singles',
                    'past-montpellier-atp-singles',
                    'past-marseille-atp-singles',
                    'past-cordoba-atp-singles',
                    'past-dallas-atp-singles',
                    # buenos aires
                    # rotterdam
                    # delray beach
                    'past-doha-atp-singles',
                    'past-rio-de-janeiro-atp-singles',
                    'past-santiago-atp-singles',
                    'past-acapulco-atp-singles',
                    'past-dubai-atp-singles',
                    'past-indian-wells-atp-singles',
                    'past-miami-atp-singles',
                    'past-estoril-atp-singles',
                    'past-houston-atp-singles',
                    'past-marrakech-atp-singles',
                    'past-monte-carlo-atp-singles',
                    'past-munich-atp-singles',
                    'past-bucharest-atp-singles',
                    'past-barcelona-atp-singles',
                    'past-madrid-atp-singles',
                    'past-rome-atp-singles', 
                    'past-lyon-atp-singles',
                    'past-geneva-atp-singles',
                    'past-french-open-atp-singles', 
                    'past-stuttgart-atp-singles',
                    'past-hertogenbosch-atp-singles',
                    'past-halle-atp-singles',
                    'past-london-atp-singles',
                    'past-mallorca-atp-singles',
                    'past-eastbourne-atp-singles',
                    'past-wimbledon-atp-singles',
                    ]

# %%
PATIENCE = 80 # 100
N_EPOCHS = 2000 # 2000
LEARNING_RATE = 5e-4 # 5e-4
WEIGHT_DECAY = 5e-4 # 1e-6
DROPOUT = 0.4 # 0.6
N_UNITS = 8 # 16
N_UNITS_OVERALL = 8 # 4
N_UNITS_SURFACE = 8 # 4
STEP_SIZE = 15 # 30
GAMMA = 0.9 # 0.9
TOURNAMENT_HIDDEN = 2 # 2
PLAYER_HIDDEN = 16 # 20
HIDDEN = 16 # 32


class TennisMatchPredictor(nn.Module):
    def __init__(self, input_shapes):
        super(TennisMatchPredictor, self).__init__()
        self.fctournament = nn.Linear(input_shapes[0], TOURNAMENT_HIDDEN) 
        self.fcplayer1 = nn.Linear(input_shapes[1], PLAYER_HIDDEN) 
        self.fc2player1 = nn.Linear(PLAYER_HIDDEN, PLAYER_HIDDEN)
        self.fcplayer2 = nn.Linear(input_shapes[2], PLAYER_HIDDEN) 
        self.fc2player2 = nn.Linear(PLAYER_HIDDEN, PLAYER_HIDDEN)
        self.gru_h2h_overall = nn.GRU(1, N_UNITS_OVERALL, batch_first=True, dropout=DROPOUT)
        self.gru_h2h_surface = nn.GRU(1, N_UNITS_SURFACE, batch_first=True, dropout=DROPOUT)
        self.gru_shape_overall_player1 = nn.GRU(1, N_UNITS, batch_first=True, dropout=DROPOUT)
        self.gru_shape_overall_player2 = nn.GRU(1, N_UNITS, batch_first=True, dropout=DROPOUT)
        self.fc1 = nn.Linear(TOURNAMENT_HIDDEN + PLAYER_HIDDEN + PLAYER_HIDDEN + N_UNITS_OVERALL + N_UNITS_SURFACE + N_UNITS + N_UNITS, HIDDEN)
        self.fc2 = nn.Linear(HIDDEN, 1)

    def forward(self, 
                tournament_features, 
                player1_features, 
                player2_features, 
                h2h_overall, 
                h2h_surface, 
                shape_overall_player1, 
                shape_overall_player2,
                tournament_mask=None,
                player1_mask=None, 
                player2_mask=None, 
                h2h_overall_mask=None, 
                h2h_surface_mask=None, 
                shape_overall_player1_mask=None, 
                shape_overall_player2_mask=None):
        
        # x1 = F.tanh(self.fctournament(tournament_features))
        x1 = tournament_features
        x2 = F.sigmoid(self.fcplayer1(player1_features))
        x2 = F.tanh(self.fc2player1(x2))
        x3 = F.sigmoid(self.fcplayer2(player2_features))
        x3 = F.tanh(self.fc2player2(x3))

        # Reverse the sequence for GRU processing
        h2h_overall = torch.flip(h2h_overall, dims=[1]).unsqueeze(-1)
        h2h_surface = torch.flip(h2h_surface, dims=[1]).unsqueeze(-1)
        shape_overall_player1 = torch.flip(shape_overall_player1, dims=[1]).unsqueeze(-1)
        shape_overall_player2 = torch.flip(shape_overall_player2, dims=[1]).unsqueeze(-1)

        if h2h_overall_mask is not None:
            h2h_overall_mask = torch.flip(h2h_overall_mask, dims=[1]).unsqueeze(-1)
        if h2h_surface_mask is not None:
            h2h_surface_mask = torch.flip(h2h_surface_mask, dims=[1]).unsqueeze(-1)
        if shape_overall_player1_mask is not None:
            shape_overall_player1_mask = torch.flip(shape_overall_player1_mask, dims=[1]).unsqueeze(-1)
        if shape_overall_player2_mask is not None:
            shape_overall_player2_mask = torch.flip(shape_overall_player2_mask, dims=[1]).unsqueeze(-1)

        def apply_gru_with_mask(gru, x, mask):
            batch_size, seq_len, _ = x.size()
            hidden = torch.zeros(batch_size, gru.hidden_size).to(x.device)
            for t in range(seq_len):
                input_t = x[:, t, :]
                mask_t = mask[:, t, :].float()
                out, hidden = gru(input_t.unsqueeze(1), hidden.unsqueeze(0))
                hidden = hidden.squeeze(0) * mask_t + hidden.squeeze(0) * (1 - mask_t)
            return hidden

        x4 = apply_gru_with_mask(self.gru_h2h_overall, h2h_overall, h2h_overall_mask)
        x4 = F.tanh(x4)

        x5 = apply_gru_with_mask(self.gru_h2h_surface, h2h_surface, h2h_surface_mask)
        x5 = F.tanh(x5)

        x6 = apply_gru_with_mask(self.gru_shape_overall_player1, shape_overall_player1, shape_overall_player1_mask)
        x6 = F.tanh(x6)

        x7 = apply_gru_with_mask(self.gru_shape_overall_player2, shape_overall_player2, shape_overall_player2_mask)
        x7 = F.tanh(x7)

        x = torch.cat((x1, x2, x3, x4, x5, x6, x7), 1)
        x = F.dropout(x, p=DROPOUT)
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        return x

# %%
PROB_THRESHOLD = 0.7

# Kelly criterion
def kelly_criterion(odds, prob, safe=0.1):
    return (prob - ((1- prob)/(odds)))*safe

# %%
for i in tqdm(range(len(tournaments_ordered_2024))):
    if i == 0 :
        continue
    train_tournaments = tournaments_2023 + tournaments_ordered_2024[:i]
    test_tournamets = [tournaments_ordered_2024[i]]
    print(f'Train tournaments until : {train_tournaments[-1]}')
    print(f'Test tournament : {test_tournamets[0]}')
    tennis_dataset = TennisMatchDataset(train_tournaments, verbose = True)
    list_vectors, list_labels, lst_match_id, nb_errors = tennis_dataset.get_past_vectors(verbose = False)
    input_shapes = []
    for i in range(len(list_vectors[0])):
        tqdm.write(f'Input number {i} is shape : {len(list_vectors[0][i])}')
        input_shapes.append(len(list_vectors[0][i]))
    lst_tournaments = []
    new_list_vectors = []
    new_list_labels = []
    for i in tqdm(range(len(list_vectors))) :
        vector = list_vectors[i]
        num_padding = 0
        for spe_vec in vector :
            num_padding += spe_vec.count(c.PADDING)
        if num_padding < MAX_PADDED and list_labels[i] != c.PADDING:
            new_list_vectors.append(vector)
            new_list_labels.append(list_labels[i])
        else :
            tqdm.write(f'padding : {num_padding} for match_id : {lst_match_id[i]}')
    tqdm.write(f'Number of vectors after removing vectors with too much missing values : {len(new_list_vectors)} over {len(list_vectors)}')

        # create 7 tensors : [tournament_features_vector, player1_features_vector, player2_features_vector, h2h_overall_vector, h2h_surface_vector, shape_overall_player1, shape_overall_player2]
    tournament_features_vector = []
    player1_features_vector = []
    player2_features_vector = []
    h2h_overall_vector = []
    h2h_surface_vector = []
    shape_overall_player1_vector = []
    shape_overall_player2_vector = []

    for vector in new_list_vectors:
        tournament_features_vector.append(vector[0])
        player1_features_vector.append(vector[1])
        player2_features_vector.append(vector[2])
        h2h_overall_vector.append(vector[3])
        h2h_surface_vector.append(vector[4])
        shape_overall_player1_vector.append(vector[5])
        shape_overall_player2_vector.append(vector[6])

    # convert to pytorch tensor
    tournament_features_tensor = torch.tensor(tournament_features_vector, dtype=torch.float)
    tournament_features_mask = torch.zeros_like(tournament_features_tensor)
    tournament_features_mask[tournament_features_tensor != c.PADDING] = 1.
    player1_features_tensor = torch.tensor(player1_features_vector, dtype=torch.float)
    player1_features_mask = torch.zeros_like(player1_features_tensor)
    player1_features_mask[player1_features_tensor != c.PADDING] = 1.
    player2_features_tensor = torch.tensor(player2_features_vector, dtype=torch.float)
    player2_features_mask = torch.zeros_like(player2_features_tensor)
    player2_features_mask[player2_features_tensor != c.PADDING] = 1.
    h2h_overall_tensor = torch.tensor(h2h_overall_vector, dtype=torch.float)
    h2h_overall_mask = torch.zeros_like(h2h_overall_tensor)
    h2h_overall_mask[h2h_overall_tensor != c.PADDING] = 1.
    h2h_surface_tensor = torch.tensor(h2h_surface_vector, dtype=torch.float)
    h2h_surface_mask = torch.zeros_like(h2h_surface_tensor)
    h2h_surface_mask[h2h_surface_tensor != c.PADDING] = 1.
    shape_overall_player1_tensor = torch.tensor(shape_overall_player1_vector, dtype=torch.float)
    shape_overall_player1_mask = torch.zeros_like(shape_overall_player1_tensor)
    shape_overall_player1_mask[shape_overall_player1_tensor != c.PADDING] = 1.
    shape_overall_player2_tensor = torch.tensor(shape_overall_player2_vector, dtype=torch.float)
    shape_overall_player2_mask = torch.zeros_like(shape_overall_player2_tensor)
    shape_overall_player2_mask[shape_overall_player2_tensor != c.PADDING] = 1.

    label_vector = []
    for label in new_list_labels:
        label_vector.append(label)

    label_tensor = torch.tensor(label_vector)

    dataset = TensorDataset(tournament_features_tensor, 
                            tournament_features_mask, 
                            player1_features_tensor, 
                            player1_features_mask, 
                            player2_features_tensor, 
                            player2_features_mask,
                            h2h_overall_tensor, 
                            h2h_overall_mask, 
                            h2h_surface_tensor, 
                            h2h_surface_mask, 
                            shape_overall_player1_tensor, 
                            shape_overall_player1_mask, 
                            shape_overall_player2_tensor, 
                            shape_overall_player2_mask, 
                            label_tensor)

    # split the dataset into train and validation 
    # train_size = int(0.85 * len(dataset))
    # val_size = len(dataset) - train_size
    # train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
    N_FOLDS = 5
    kf = KFold(n_splits=N_FOLDS, shuffle=True)

    # Initialize lists to store the results
    all_train_losses = []
    all_val_losses = []
    all_last_indexes = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(dataset)):
        tqdm.write(f"Fold {fold + 1}")
        
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)
        
        train_dataloader = DataLoader(train_subset, batch_size=64, shuffle=True)
        val_dataloader = DataLoader(val_subset, batch_size=64, shuffle=False)

        model = TennisMatchPredictor(input_shapes)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
        lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=STEP_SIZE, gamma=GAMMA)

        fold_train_losses = []
        fold_val_losses = []

        patience_counter = 0
        MIN_VAL_LOSS = np.inf
        BEST_MODEL = None
        INDEX_EPOCH = 0
        
        for epoch in tqdm(range(N_EPOCHS)):
            train_loss = 0.0
            val_loss = 0.0
            model.train()
            for data in train_dataloader:
                (tournament_features, tournament_mask, player1_features, player1_mask,
                player2_features, player2_mask, h2h_overall, h2h_overall_mask, 
                h2h_surface, h2h_surface_mask, shape_overall_player1, shape_overall_player1_mask, 
                shape_overall_player2, shape_overall_player2_mask, labels) = data
                optimizer.zero_grad()
                outputs = model(tournament_features, player1_features, player2_features, 
                                h2h_overall, h2h_surface, shape_overall_player1, shape_overall_player2,
                                tournament_mask, player1_mask, player2_mask, h2h_overall_mask, 
                                h2h_surface_mask, shape_overall_player1_mask, shape_overall_player2_mask)
                loss = criterion(outputs, labels.unsqueeze(1).float())
                loss.backward()
                optimizer.step()
                train_loss += loss.item()
            lr_scheduler.step()

            

            
            model.eval()
            with torch.no_grad():
                for data in val_dataloader:
                    (tournament_features, tournament_mask, player1_features, player1_mask,
                    player2_features, player2_mask, h2h_overall, h2h_overall_mask, 
                    h2h_surface, h2h_surface_mask, shape_overall_player1, shape_overall_player1_mask, 
                    shape_overall_player2, shape_overall_player2_mask, labels) = data
                    outputs = model(tournament_features, player1_features, player2_features, 
                                    h2h_overall, h2h_surface, shape_overall_player1, shape_overall_player2,
                                    tournament_mask, player1_mask, player2_mask, h2h_overall_mask, 
                                    h2h_surface_mask, shape_overall_player1_mask, shape_overall_player2_mask)
                    loss = criterion(outputs, labels.unsqueeze(1).float())
                    val_loss += loss.item()
                
                fold_train_losses.append(train_loss / len(train_dataloader))
                fold_val_losses.append(val_loss / len(val_dataloader))
                if epoch % 100 == 0:
                    all_weights = torch.cat([x.view(-1) for x in model.parameters()])
                    tqdm.write(f'Fold {fold + 1}, Epoch {epoch + 1}, Train Loss: {train_loss / len(train_dataloader):.2f}, Validation Loss: {val_loss / len(val_dataloader):.2f}, lr: {lr_scheduler.get_last_lr()[0]:.2e}, Weight norm: {all_weights.norm():.2f}')
                if val_loss < MIN_VAL_LOSS:
                    MIN_VAL_LOSS = val_loss
                    patience_counter = 0
                    BEST_MODEL = model.state_dict()
                    INDEX_EPOCH = epoch
                else:
                    patience_counter += 1
                if patience_counter == PATIENCE:
                    tqdm.write(f'       --> Early stopping at epoch {epoch + 1} with validation loss: {MIN_VAL_LOSS/len(val_dataloader):.2f}')
                    break
            
            all_train_losses.append(fold_train_losses)
            all_val_losses.append(fold_val_losses)
            all_last_indexes.append(INDEX_EPOCH)
            
            # Save the best model for each fold
            torch.save(BEST_MODEL, f'{c2.REPO_PATH}/tennis/models/best_model_fold_{fold + 1}.pth')


    tennis_test_dataset = TennisMatchDataset(test_tournamets, verbose = False)
    nb_errors = 0
    list_vectors_test = []
    list_labels_test = []
    list_matches_ids_test = []

    list_vectors_test, list_labels_test, list_matches_ids_test, nb_errors = tennis_test_dataset.get_past_vectors()
    input_shapes = []
    for i in range(len(list_vectors_test[0])):
        input_shapes.append(len(list_vectors_test[0][i]))
         
    new_list_vectors_test = []
    new_list_labels_test = []
    new_list_matches_ids_test = []

    for i in tqdm(range(len(list_vectors_test))) :
        vector = list_vectors_test[i]
        num_padding = 0
        for spe_vec in vector :
            num_padding += spe_vec.count(c.PADDING)
        if num_padding < MAX_PADDED and list_labels_test[i] != c.PADDING:
            new_list_vectors_test.append(vector)
            new_list_labels_test.append(list_labels_test[i])
            new_list_matches_ids_test.append(list_matches_ids_test[i])

    if len(new_list_vectors_test) == 0:
        print('No data to predict')
        continue

    tournament_features_vector_test = []
    player1_features_vector_test = []
    player2_features_vector_test = []
    h2h_overall_vector_test = []
    h2h_surface_vector_test = []
    shape_overall_player1_vector_test = []
    shape_overall_player2_vector_test = []

    for vector in new_list_vectors_test:
        tournament_features_vector_test.append(vector[0])
        player1_features_vector_test.append(vector[1])
        player2_features_vector_test.append(vector[2])
        h2h_overall_vector_test.append(vector[3])
        h2h_surface_vector_test.append(vector[4])
        shape_overall_player1_vector_test.append(vector[5])
        shape_overall_player2_vector_test.append(vector[6])

    # convert to pytorch tensor
    tournament_features_tensor_test = torch.tensor(tournament_features_vector_test, dtype=torch.float)
    tournament_features_mask_test = torch.zeros_like(tournament_features_tensor_test)
    tournament_features_mask_test[tournament_features_tensor_test != c.PADDING] = 1.
    player1_features_tensor_test = torch.tensor(player1_features_vector_test, dtype=torch.float)
    player1_features_mask_test = torch.zeros_like(player1_features_tensor_test)
    player1_features_mask_test[player1_features_tensor_test != c.PADDING] = 1.
    player2_features_tensor_test = torch.tensor(player2_features_vector_test, dtype=torch.float)
    player2_features_mask_test = torch.zeros_like(player2_features_tensor_test)
    player2_features_mask_test[player2_features_tensor_test != c.PADDING] = 1.
    h2h_overall_tensor_test = torch.tensor(h2h_overall_vector_test, dtype=torch.float)
    h2h_overall_mask_test = torch.zeros_like(h2h_overall_tensor_test)
    h2h_overall_mask_test[h2h_overall_tensor_test != c.PADDING] = 1.
    h2h_surface_tensor_test = torch.tensor(h2h_surface_vector_test, dtype=torch.float)
    h2h_surface_mask_test = torch.zeros_like(h2h_surface_tensor_test)
    h2h_surface_mask_test[h2h_surface_tensor_test != c.PADDING] = 1.
    shape_overall_player1_tensor_test = torch.tensor(shape_overall_player1_vector_test, dtype=torch.float)
    shape_overall_player1_mask_test = torch.zeros_like(shape_overall_player1_tensor_test)
    shape_overall_player1_mask_test[shape_overall_player1_tensor_test != c.PADDING] = 1.
    shape_overall_player2_tensor_test = torch.tensor(shape_overall_player2_vector_test, dtype=torch.float)
    shape_overall_player2_mask_test = torch.zeros_like(shape_overall_player2_tensor_test)
    shape_overall_player2_mask_test[shape_overall_player2_tensor_test != c.PADDING] = 1.

    label_vector = []
    for label in new_list_labels_test:
        label_vector.append(label)

    label_tensor_test = torch.tensor(label_vector)

    test_dataset = TensorDataset(tournament_features_tensor_test, 
                                tournament_features_mask_test, 
                                player1_features_tensor_test, 
                                player1_features_mask_test, 
                                player2_features_tensor_test, 
                                player2_features_mask_test,
                                h2h_overall_tensor_test, 
                                h2h_overall_mask_test, 
                                h2h_surface_tensor_test, 
                                h2h_surface_mask_test, 
                                shape_overall_player1_tensor_test, 
                                shape_overall_player1_mask_test, 
                                shape_overall_player2_tensor_test, 
                                shape_overall_player2_mask_test, 
                                label_tensor_test)

    test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)

    all_predictions = []
    for j in range(N_FOLDS):
        model = TennisMatchPredictor(input_shapes)
        model.load_state_dict(torch.load(f'{c2.REPO_PATH}/tennis/models/best_model_fold_{j + 1}.pth'))
        model.eval()
        predictions = []
        with torch.no_grad():
            test_loss = 0.0
            for i, data in enumerate(test_dataloader):
                tournament_features, tournament_mask, player1_features, player1_mask, player2_features, player2_mask, h2h_overall, h2h_overall_mask, h2h_surface, h2h_surface_mask, shape_overall_player1, shape_overall_player1_mask, shape_overall_player2, shape_overall_player2_mask, labels = data
                outputs = model(tournament_features = tournament_features, 
                                player1_features = player1_features, 
                                player2_features = player2_features, 
                                h2h_overall = h2h_overall, 
                                h2h_surface = h2h_surface, 
                                shape_overall_player1 = shape_overall_player1, 
                                shape_overall_player2 = shape_overall_player2,
                                tournament_mask = tournament_mask, 
                                player1_mask = player1_mask, 
                                player2_mask = player2_mask, 
                                h2h_overall_mask = h2h_overall_mask,
                                h2h_surface_mask = h2h_surface_mask,
                                shape_overall_player1_mask = shape_overall_player1_mask,
                                shape_overall_player2_mask = shape_overall_player2_mask
                                )    
                predictions.append(outputs)        
                loss = criterion(outputs, labels.unsqueeze(1).float())
                test_loss += loss.item()
            print(f'Test Loss: for {j+1} : {test_loss/len(test_dataloader):.2f}')
        # find the matches where the model is the most confident and was right
        predictions = torch.cat(predictions).flatten()
        all_predictions.append(predictions)

    all_predictions = torch.stack(all_predictions)
    predictions = all_predictions.mean(dim=0)

    # get the indexes of the matches where the model was right
    # create data frame with the predictions and the labels and the match ids
    df = pd.DataFrame(columns=['match_id', 'predictions', 'labels'])
    df['predictions'] = predictions
    df['labels'] = label_tensor_test
    df['match_id'] = new_list_matches_ids_test
    # order the data frame by predictions values
    df = df.sort_values(by='predictions', ascending=False)

    # fetch the odds of betclic for the matches
    odds_1_list = []
    odds_2_list = []
    prob_list = []
    for match_id in df['match_id']:
        match_odds =tennis_test_dataset.get_match(match_id).get_odds()
        odds_found = False
        for match_odd in match_odds:
            if match_odd['bookmaker'] == 'Betclic.fr':
                odds_found = True
                odds_1_list.append(float(match_odd['odds'][0]))
                odds_2_list.append(float(match_odd['odds'][1]))
                player1odd = float(match_odd['odds'][0])
                player2odd = float(match_odd['odds'][1])
                prob_win_player1 = 1/player1odd
                prob_win_player2 = 1/player2odd
                # normalize the probabilities
                prob_sum = prob_win_player1 + prob_win_player2
                prob_win_player1 = prob_win_player1/prob_sum
                prob_win_player2 = prob_win_player2/prob_sum
                prob_list.append(2*prob_win_player1-1)
                break
        if not odds_found:
            odds_1_list.append(None)
            odds_2_list.append(None)
            prob_list.append(None) 

    df['odds_1'] = odds_1_list
    df['odds_2'] = odds_2_list
    df['bookmaker_pred'] = prob_list
    df = df.loc[df['odds_1'].notnull()]

    # if predictions > 0.6 bet on player 1, if predictions < -0.6 bet on player 2
    bet_on_player_1_df = df.loc[df['predictions'] > PROB_THRESHOLD].copy()
    bet_on_player_1_df['prediction_prob']= bet_on_player_1_df['predictions'].apply(lambda x : (1+x)/2)
    bet_on_player_1_df['kelly_criterion'] = bet_on_player_1_df.apply(lambda row : kelly_criterion(row['odds_1'], row['prediction_prob']), axis=1)

    bet_on_player_2_df = df.loc[df['predictions'] < -PROB_THRESHOLD].copy()
    bet_on_player_2_df['prediction_prob']= bet_on_player_2_df['predictions'].apply(lambda x : (1-x)/2)
    bet_on_player_2_df['kelly_criterion'] = bet_on_player_2_df.apply(lambda row : kelly_criterion(row['odds_2'], row['prediction_prob']), axis=1)
    account_values = []
    total_amount = INIT_AMOUNT
    account_values.append(total_amount)
    for i, row in bet_on_player_1_df.iterrows():
        player1 = tennis_test_dataset.get_match(row['match_id']).get_players()[0]
        player2 = tennis_test_dataset.get_match(row['match_id']).get_players()[1]
        amout_to_bet = max(row['kelly_criterion']*total_amount, 0)
        if row['labels'] == 1:
            total_amount += amout_to_bet*(row['odds_1']-1)
            print(f"{GREEN}Match : {row['match_id']} {player1} - {player2}, bet on player 1 ({row['prediction_prob']:.2f}), amount to bet : {amout_to_bet:.2f}, odds : {row['odds_1']:.2f}, label : {row['labels']:.2f}, total amount : {total_amount:.2f}{RESET}")
        else:
            total_amount -= amout_to_bet
            print(f"{RED}Match : {row['match_id']} {player1} - {player2}, bet on player 1 ({row['prediction_prob']:.2f}), amount to bet : {amout_to_bet:.2f}, odds : {row['odds_1']:.2f}, label : {row['labels']:.2f}, total amount : {total_amount:.2f}{RESET}")
        account_values.append(total_amount)

    for i, row in bet_on_player_2_df.iterrows():
        player1 = tennis_test_dataset.get_match(row['match_id']).get_players()[0]
        player2 = tennis_test_dataset.get_match(row['match_id']).get_players()[1]
        amout_to_bet = max(row['kelly_criterion']*total_amount, 0)
        if row['labels'] == -1:
            total_amount += amout_to_bet*(row['odds_2']-1)
            print(f"{GREEN}Match : {row['match_id']} {player1} - {player2}, bet on player 2 ({row['prediction_prob']:.2f}), amount to bet : {amout_to_bet:.2f}, odds : {row['odds_2']:.2f}, label : {row['labels']:.2f}, total amount : {total_amount:.2f}{RESET}")
        else:
            total_amount -= amout_to_bet
            print(f"{RED}Match : {row['match_id']} {player1} - {player2}, bet on player 2 ({row['prediction_prob']:.2f}), amount to bet : {amout_to_bet:.2f}, odds : {row['odds_2']:.2f}, label : {row['labels']:.2f}, total amount : {total_amount:.2f}{RESET}")
        account_values.append(total_amount)

print(f"\nTotal amount after betting : {total_amount:.2f}")
if total_amount >= INIT_AMOUNT:
    print(f"{GREEN}Relative won {(total_amount-INIT_AMOUNT)/INIT_AMOUNT*100:.2f}%{RESET}")
else:
    print(f"{RED}Relative lost {(INIT_AMOUNT-total_amount)/INIT_AMOUNT*100:.2f}%{RESET}")

plt.figure(figsize=(10, 5))
plt.plot(account_values, label='Account value', color='blue', marker='o')
plt.xlabel('Match')
plt.ylabel('Amount')
plt.title('Account value over time')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
#   0%|          | 0/35 [00:00<?, ?it/s]
# Train tournaments until : past-brisbane-atp-singles
# Test tournament : past-hong-kong-atp-singles
# Loading data for tournaments {'past-indian-wells-2023-atp-singles', 'past-hertogenbosch-2023-atp-singles', 'past-bastad-2023-atp-singles', 'past-barcelona-2023-atp-singles', 'past-estoril-2023-atp-singles', 'past-hamburg-2023-atp-singles', 'past-stockholm-2023-atp-singles', 'past-lyon-2023-atp-singles', 'past-mallorca-2023-atp-singles', 'past-french-open-2023-atp-singles', 'past-dallas-2023-atp-singles', 'past-washington-2023-atp-singles', 'past-chengdu-2023-atp-singles', 'past-newport-2023-atp-singles', 'past-basel-2023-atp-singles', 'past-dubai-2023-atp-singles', 'past-stuttgart-2023-atp-singles', 'past-atlanta-2023-atp-singles', 'past-winston-salem-2023-atp-singles', 'past-doha-2023-atp-singles', 'past-zhuhai-2023-atp-singles', 'past-rio-de-janeiro-2023-atp-singles', 'past-geneva-2023-atp-singles', 'past-madrid-2023-atp-singles', 'past-paris-2023-atp-singles', 'past-houston-2023-atp-singles', 'past-wimbledon-2023-atp-singles', 'past-gstaad-2023-atp-singles', 'past-eastbourne-2023-atp-singles', 'past-metz-2023-atp-singles', 'past-london-2023-atp-singles', 'past-munich-2023-atp-singles', 'past-miami-2023-atp-singles', 'past-montpellier-2023-atp-singles', 'past-antwerp-2023-atp-singles', 'past-halle-2023-atp-singles', 'past-australian-open-2023-atp-singles', 'past-us-open-2023-atp-singles', 'past-marseille-2023-atp-singles', 'past-acapulco-2023-atp-singles', 'past-adelaide-2023-atp-singles', 'past-monte-carlo-2023-atp-singles', 'past-beijing-2023-atp-singles', 'past-cordoba-2023-atp-singles', 'past-vienna-2023-atp-singles', 'past-brisbane-atp-singles', 'past-marrakech-2023-atp-singles', 'past-tokyo-2023-atp-singles', 'past-auckland-2023-atp-singles', 'past-shanghai-2023-atp-singles', 'past-umag-2023-atp-singles', 'past-cincinnati-2023-atp-singles', 'past-santiago-2023-atp-singles', 'past-rome-2023-atp-singles', 'past-finals-turin-2023-atp-singles'} ...
# ... loaded 3594 matches
# Updating id table ...
# ... id table updated
# 100%|██████████| 55/55 [00:00<00:00, 77.50it/s]
# Input number 0 is shape : 2
# Input number 1 is shape : 54
# Input number 2 is shape : 54
# Input number 3 is shape : 4
# Input number 4 is shape : 4
# Input number 5 is shape : 15
# Input number 6 is shape : 15
#   0%|          | 0/2598 [00:00<?, ?it/s]
# padding : 39 for match_id : xQwqr8Fj
# padding : 37 for match_id : pfNlpBQ5
# padding : 33 for match_id : WhUAQL1K
# padding : 35 for match_id : bXXQWdJg
# padding : 36 for match_id : l8L5o2Xg
# padding : 39 for match_id : E9m9Snae
# padding : 38 for match_id : dteUCDjl
# padding : 40 for match_id : ljEywjcl
# padding : 36 for match_id : CzQWN8TG
# padding : 36 for match_id : jRnkCQne
# padding : 39 for match_id : Y3ZVDFaC
# padding : 40 for match_id : 88zoqD0I
# padding : 34 for match_id : nmXJGHFg
# padding : 39 for match_id : QwWNFyVa
# padding : 41 for match_id : v7ul3bof
# padding : 35 for match_id : rFhWaXwg
# padding : 39 for match_id : YPW6J3Ih
# padding : 36 for match_id : xGbesSRd
# padding : 37 for match_id : lIGmKeQ0
# padding : 41 for match_id : EZIEYfuf
# padding : 38 for match_id : jPPxPpCS
# padding : 33 for match_id : M307vQBF
# padding : 39 for match_id : pryVxeoH
# padding : 36 for match_id : 6T17UQgj
# padding : 46 for match_id : 08bazdQB
# padding : 40 for match_id : 6B4CkYUM
# padding : 40 for match_id : OYZYyF0N
# padding : 39 for match_id : OEBdarbl
# padding : 37 for match_id : WbRLurq8
# padding : 40 for match_id : t8iBuN9q
# padding : 47 for match_id : 0t88De77
# padding : 44 for match_id : z9DAGTFt
# padding : 38 for match_id : 2wQOYmgM
# padding : 40 for match_id : 2eN4kbw8
# padding : 42 for match_id : O401PObB
# padding : 45 for match_id : AuJG1gt8
# padding : 39 for match_id : dMlLv13M
# padding : 35 for match_id : 8MHDzySn
# padding : 43 for match_id : M7Adt0a1
# padding : 42 for match_id : Sndjxup8
# padding : 40 for match_id : dGTBIGoR
# padding : 44 for match_id : fP8pT6an
# padding : 36 for match_id : I3mglaDS
# padding : 38 for match_id : IJXeELvJ
# padding : 43 for match_id : xllm4Bja
# padding : 39 for match_id : EBxmVveF
# padding : 37 for match_id : j72AXrus
# padding : 45 for match_id : Imcdxsph
# padding : 46 for match_id : 2TCvR7At
# padding : 47 for match_id : hOpO5OR3
# padding : 36 for match_id : SEpxJAIJ
# padding : 43 for match_id : Gvmi3V55
# padding : 42 for match_id : QVNMsIvL
# padding : 41 for match_id : Iq3odmB6
# padding : 65 for match_id : Aeq9eVxn
# padding : 39 for match_id : xW4G4hCQ
# padding : 36 for match_id : O0WeDH5q
# padding : 57 for match_id : 4tkecA40
# padding : 46 for match_id : 4CJNVPLA
# padding : 48 for match_id : zBhnYIs9
# padding : 43 for match_id : AHY7AFk2
# padding : 68 for match_id : 4I686EsE
# padding : 57 for match_id : r95C5YdK
# padding : 47 for match_id : Eidr0CKs
# padding : 49 for match_id : z7pibjkf
# padding : 64 for match_id : Qew4elZC
# padding : 48 for match_id : rXmadUJ6
# padding : 40 for match_id : 4AI3S8Sp
# padding : 54 for match_id : nBejfLLP
# padding : 44 for match_id : 6exNlaqm
# padding : 45 for match_id : jZUkJiRJ
# padding : 40 for match_id : xWt8f8lJ
# padding : 48 for match_id : KKiSocT5
# padding : 45 for match_id : hYkzpybI
# padding : 46 for match_id : bBjWpHrC
# padding : 45 for match_id : v9zVnwEa
# padding : 54 for match_id : h0vLnnXr
# padding : 52 for match_id : 8MmFFSm3
# padding : 61 for match_id : lYQKIh0C
# padding : 43 for match_id : Ic0l0YVP
# padding : 63 for match_id : drtSCQXL
# padding : 56 for match_id : vTWounCj
# padding : 38 for match_id : ObJcwBOC
# padding : 43 for match_id : 6Fdnih5o
# padding : 79 for match_id : KWPELWvK
# padding : 65 for match_id : lQKILocA
# padding : 61 for match_id : rgehDPy2
# padding : 49 for match_id : AucpFo7k
# padding : 87 for match_id : nobIlnb8
# padding : 62 for match_id : hOxqzmqF
# padding : 50 for match_id : ljWiYQDR
# padding : 49 for match_id : b1wuyTT8
# padding : 62 for match_id : tnGjWwrs
# padding : 43 for match_id : GOAFQZBI
# padding : 73 for match_id : bPHNS4yk
# padding : 53 for match_id : QZH2TySa
# padding : 67 for match_id : fF9JPgRO
# padding : 67 for match_id : 8b77Ses6
# padding : 69 for match_id : 42dlE5Me
# padding : 50 for match_id : KAvyx9E2
# padding : 60 for match_id : jaIJTpMr
# padding : 69 for match_id : 6RtmZ6bL
# padding : 65 for match_id : QycMm6DE
# padding : 38 for match_id : 4ACH8JFl
# padding : 44 for match_id : d4whpjQO
# padding : 40 for match_id : GSlhXlpi
# padding : 39 for match_id : Y7XY7vSR
# padding : 39 for match_id : rkeJvH27
# padding : 35 for match_id : vwp2gfoB
# padding : 50 for match_id : 6LXGYsb4
# padding : 40 for match_id : zToFnJFO
# padding : 41 for match_id : 4O3a77WG
# padding : 35 for match_id : KEzHVMDr
# padding : 39 for match_id : vD2su6sQ
# padding : 48 for match_id : CMvHsKKL
# padding : 37 for match_id : pKQGwOWg
# padding : 41 for match_id : Q3mLWweq
# padding : 43 for match_id : GrNXaoI7
# padding : 44 for match_id : IXIJ1PM2
# padding : 45 for match_id : joHRa3iF
# padding : 42 for match_id : Im1GOUf8
# padding : 43 for match_id : WfLL2mYl
# padding : 49 for match_id : AoKP17me
# padding : 41 for match_id : 2PzXwMUe
# padding : 48 for match_id : tGZzwtp2
# padding : 51 for match_id : QgKLhf4p
# padding : 46 for match_id : GzoQpFPk
# padding : 55 for match_id : v7XXpX9q
# padding : 53 for match_id : 8xMz5h1F
# padding : 30 for match_id : Iugxq51j
# padding : 37 for match_id : SpudVlWL
# padding : 37 for match_id : 2FDlScRt
# padding : 38 for match_id : Q3wOf47R
# padding : 34 for match_id : hllFoquC
# padding : 42 for match_id : 08YYcgj2
# padding : 54 for match_id : WUgIS38S
# padding : 42 for match_id : SQr9hxmh
# padding : 41 for match_id : WdYmpMzi
# padding : 40 for match_id : re2xih93
# padding : 47 for match_id : nesdbsb1
# padding : 39 for match_id : bcaYjL6J
# padding : 44 for match_id : 0C2EIym1
# padding : 56 for match_id : QeaMJPgD
# padding : 45 for match_id : Y3P3HNaj
# padding : 47 for match_id : GSllPZId
# padding : 53 for match_id : nPj8AgDU
# padding : 42 for match_id : CfO7GsFd
# padding : 43 for match_id : 8Yi4BZcO
# padding : 52 for match_id : QkMIUdbn
# padding : 47 for match_id : 6guPO57G
# padding : 59 for match_id : 6c5Woks5
# padding : 61 for match_id : xIDFkXst
# padding : 60 for match_id : fTjPclbm
# padding : 93 for match_id : pIuwSkE3
# padding : 53 for match_id : x2uq68ip
# padding : 88 for match_id : GryZSVbc
# padding : 82 for match_id : zmbn5S6j
# padding : 36 for match_id : EomyO36k
# padding : 43 for match_id : 0Mkwqxoa
# padding : 36 for match_id : 2NNdbUUJ
# padding : 43 for match_id : YXtn2gR8
# padding : 41 for match_id : 4YYMSOa9
# padding : 37 for match_id : WbyTQqI8
# padding : 36 for match_id : W0zxjtd1
# padding : 42 for match_id : beMVw4wm
# padding : 40 for match_id : vBLNPIZI
# padding : 42 for match_id : 4IjQ5JR3
# padding : 37 for match_id : vJeosLWC
# padding : 43 for match_id : fuVoUXQ4
# padding : 41 for match_id : bgHPg9vn
# padding : 49 for match_id : KpNZzqrK
# padding : 47 for match_id : vDvgYoaQ
# padding : 45 for match_id : 2RJWpv1M
# padding : 40 for match_id : KdLJAVHo
# padding : 54 for match_id : SfvpRcTh
# padding : 44 for match_id : YgdXEo8I
# padding : 41 for match_id : xWEX01Fm
# padding : 43 for match_id : dKw0Y3Ch
# padding : 46 for match_id : Ob7AwSIF
# padding : 45 for match_id : QkApzfkl
# padding : 48 for match_id : GlQltPqr
# padding : 83 for match_id : x6PIO6Z5
# padding : 43 for match_id : EcFw3Pcn
# padding : 42 for match_id : l0ykRdoS
# padding : 46 for match_id : 0hhcgUnB
# padding : 52 for match_id : tvAvBm56
# padding : 39 for match_id : EeKSiMrf
# padding : 45 for match_id : YHzX2g5f
# padding : 38 for match_id : Mwed9eSQ
# padding : 47 for match_id : jgoS3Zkl
# padding : 39 for match_id : zsT1Slzs
# padding : 48 for match_id : nHW5R8km
# padding : 58 for match_id : Cliic2cq
# padding : 48 for match_id : Ag8X8Gjc
# padding : 52 for match_id : tSZXCLLt
# padding : 68 for match_id : p043ctMg
# padding : 75 for match_id : 2yFbbM6m
# padding : 51 for match_id : xfTtBajg
# padding : 37 for match_id : bBQwknwN
# padding : 46 for match_id : IaPeHaD0
# padding : 40 for match_id : QLGScYk2
# padding : 52 for match_id : n16R2h72
# padding : 47 for match_id : Uc5EBwc3
# padding : 51 for match_id : 0SMqRpIn
# padding : 46 for match_id : SvGLcJFp
# padding : 45 for match_id : QRFVm0L8
# padding : 48 for match_id : Q9Kvmh5I
# padding : 47 for match_id : AJXrQdT1
# padding : 42 for match_id : tjlLDTXP
# padding : 50 for match_id : QaBLTfQR
# padding : 53 for match_id : UXHCVGeF
# padding : 41 for match_id : tMrhYRHg
# padding : 51 for match_id : S8cmPEYr
# padding : 47 for match_id : Aik4LWX7
# padding : 76 for match_id : v71eXoXa
# padding : 44 for match_id : EPeeNh3e
# padding : 46 for match_id : xx0bZJDm
# padding : 85 for match_id : nsIxaGAg
# padding : 52 for match_id : QXGtbzQa
# padding : 64 for match_id : 6X9U0xts
# padding : 92 for match_id : A1Ob6bIJ
# padding : 39 for match_id : 0zBolRe3
# padding : 41 for match_id : QkCTtr6C
# padding : 45 for match_id : jTVziwhm
# padding : 41 for match_id : fuLH5xaL
# padding : 43 for match_id : SQxXGZ46
# padding : 45 for match_id : OdYQUukD
# padding : 36 for match_id : S8HyYcwj
# padding : 45 for match_id : dlHbgsvf
# padding : 42 for match_id : beMVVyN2
# padding : 34 for match_id : Y5I0yXB9
# padding : 44 for match_id : Cl3Lkobg
# padding : 43 for match_id : KOTnLjT3
# padding : 46 for match_id : WlAXnqrC
# padding : 37 for match_id : xhxEVbhO
# padding : 42 for match_id : dlyftcxH
# padding : 45 for match_id : n3q1Y085
# padding : 39 for match_id : MFAWmt8h
# padding : 37 for match_id : 069zm0Nb
# padding : 58 for match_id : hpnAnas7
# padding : 43 for match_id : dY2qovhB
# padding : 47 for match_id : 6mjEoJdD
# padding : 48 for match_id : YyunMm3a
# padding : 40 for match_id : 8hUdA2ZD
# padding : 54 for match_id : lSuIUI7U
# padding : 49 for match_id : KWm2lLCf
# padding : 44 for match_id : rVbunKx5
# padding : 47 for match_id : ht6SlMhn
# padding : 40 for match_id : 4vv6XKNB
# padding : 50 for match_id : hIeuBOC2
# padding : 48 for match_id : MoyIdFC6
# padding : 58 for match_id : 2HhcWIb1
# padding : 78 for match_id : M30LBIiM
# padding : 44 for match_id : no88EK73
# padding : 44 for match_id : Wzs4scHI
# padding : 44 for match_id : QwfIvdv2
# padding : 41 for match_id : xhfgdAU9
# padding : 44 for match_id : GfLDXxwd
# padding : 36 for match_id : biz4LgwA
# padding : 46 for match_id : 670ze1B0
# padding : 39 for match_id : IRqcy1vg
# padding : 69 for match_id : SQIahQ1r
# padding : 44 for match_id : EsDgpee4
# padding : 55 for match_id : dQto1fke
# padding : 42 for match_id : WKE1chAm
# padding : 40 for match_id : x8fVugHq
# padding : 39 for match_id : boL2Bnvt
# padding : 52 for match_id : lS9231N5
# padding : 45 for match_id : Q1A2SJK1
# padding : 41 for match_id : ptbfG9Xq
# padding : 51 for match_id : xxK6A6gn
# padding : 55 for match_id : Wbcufo95
# padding : 58 for match_id : MiriyJuS
# padding : 65 for match_id : l2jvvLe9
# padding : 47 for match_id : AHvmxaQL
# padding : 49 for match_id : lzhpg5OB
# padding : 49 for match_id : MmjhiqgO
# padding : 62 for match_id : ShkrwuBF
# padding : 39 for match_id : SQjlhPwI
# padding : 58 for match_id : jBx4FPSL
# padding : 61 for match_id : nHnszBaq
# padding : 65 for match_id : xGCDYhaI
# padding : 63 for match_id : bH1RFwfh
# padding : 59 for match_id : vXb7oW6d
# padding : 71 for match_id : YRqN6tw5
# padding : 72 for match_id : x0jE828h
# padding : 67 for match_id : CIrR50hB
# padding : 79 for match_id : 0t03nCij
# padding : 42 for match_id : Y5Oguxk4
# padding : 45 for match_id : AeVIu4uE
# padding : 37 for match_id : b9gMsR0g
# padding : 40 for match_id : r5qqoyyK
# padding : 39 for match_id : WbXDtGpR
# padding : 39 for match_id : dOsHdESQ
# padding : 55 for match_id : 6sHpJelI
# padding : 41 for match_id : xt6dy7Bf
# padding : 42 for match_id : pn1V6ZUD
# padding : 39 for match_id : 8nkf9Zxp
# padding : 46 for match_id : WOE9tF0t
# padding : 39 for match_id : df8nrb14
# padding : 49 for match_id : KlezTqDL
# padding : 46 for match_id : 4t1HBbjE
# padding : 41 for match_id : 4letmFDD
# padding : 60 for match_id : f1UMwGqU
# padding : 43 for match_id : CxuIvdUN
# padding : 55 for match_id : dAGlZZio
# padding : 70 for match_id : KEMMdLWP
# padding : 52 for match_id : t6OpfWKt
# padding : 42 for match_id : zTNlgjzm
# padding : 50 for match_id : z93PjcEl
# padding : 57 for match_id : Qcdxleb7
# padding : 83 for match_id : pKMQ3ADs
# padding : 83 for match_id : 2mBL4754
# padding : 70 for match_id : OU5AMNDN
# padding : 72 for match_id : l4TFXTsh
# padding : 103 for match_id : McyU9Qko
# padding : 119 for match_id : pIsjH8cB
# padding : 77 for match_id : vusfGSCH
# padding : 66 for match_id : Klk2E6sU
# padding : 44 for match_id : SYdR43Yc
# padding : 44 for match_id : tMnOkvSh
# padding : 51 for match_id : 6FbzwCjf
# padding : 46 for match_id : hK28MBCO
# padding : 48 for match_id : dC1nnLSM
# padding : 55 for match_id : 8jP5A9Tc
# padding : 41 for match_id : x2sGfzVj
# padding : 44 for match_id : 0YmffNto
# padding : 48 for match_id : CdXMBcQ9
# padding : 46 for match_id : IFeu56Qa
# padding : 45 for match_id : OzRDJ5ug
# padding : 55 for match_id : d4NQfcyR
# padding : 56 for match_id : Us12AM3j
# padding : 49 for match_id : 4KJWHzKf
# padding : 41 for match_id : dlglYPec
# padding : 50 for match_id : vDrgXqB3
# padding : 59 for match_id : SM88mIe4
# padding : 48 for match_id : f9A0kvRi
# padding : 60 for match_id : lW94lbtb
# padding : 65 for match_id : t66djKBo
# padding : 55 for match_id : 02mBd0vF
# padding : 49 for match_id : QTp5UseM
# padding : 67 for match_id : C2jW2pSb
# padding : 60 for match_id : xSAvuY8s
# padding : 88 for match_id : zmvfOx9D
# padding : 60 for match_id : bJEDFNB4
# padding : 56 for match_id : 2cnsRvPf
# padding : 73 for match_id : O2XymMoE
# padding : 37 for match_id : OjshINhT
# padding : 35 for match_id : 46EQ5Zj1
# padding : 40 for match_id : 8A3EUKTo
# padding : 32 for match_id : SWio9dvg
# padding : 43 for match_id : MmYG8t6c
# padding : 34 for match_id : riCbr3lJ
# padding : 36 for match_id : buY4DSKt
# padding : 46 for match_id : 8feiyENg
# padding : 38 for match_id : fJBLKWbd
# padding : 38 for match_id : lYKx9ykN
# padding : 38 for match_id : x6LCrdVJ
# padding : 42 for match_id : CI4IDz4Q
# padding : 36 for match_id : SKLMtlj3
# padding : 57 for match_id : 0hr4Lhxo
# padding : 37 for match_id : roN3aVQP
# padding : 36 for match_id : EVfspyKg
# padding : 42 for match_id : nZTRw1zo
# padding : 39 for match_id : 2mZ68oxa
# padding : 44 for match_id : YaLS0BsJ
# padding : 44 for match_id : pdEXyQn7
# padding : 51 for match_id : f3oXJ6qC
# padding : 41 for match_id : GCnTKnU5
# padding : 41 for match_id : pS2Z7p67
# padding : 54 for match_id : pjwBNnCU
# padding : 44 for match_id : bV0kAGAq
# padding : 40 for match_id : AXpbQlSB
# padding : 40 for match_id : S459eUeA
# padding : 45 for match_id : GMkrynKq
# padding : 36 for match_id : WI7BZh5P
# padding : 39 for match_id : 4AIy7q4G
# padding : 43 for match_id : jiA5VvHH
# padding : 39 for match_id : dIx7Udso
# padding : 41 for match_id : 2PCI0OMB
# padding : 39 for match_id : v3BvJcoG
# padding : 45 for match_id : 6FC0MPQs
# padding : 43 for match_id : zPwnXciT
# padding : 44 for match_id : 4tkoKtRo
# padding : 41 for match_id : CftSBMaG
# padding : 51 for match_id : SAlM1KKm
# padding : 47 for match_id : KOwr4rBD
# padding : 42 for match_id : YHUXGbdA
# padding : 39 for match_id : OIoxAEKa
# padding : 42 for match_id : IFZBD0nP
# padding : 42 for match_id : 0KlDhaAa
# padding : 45 for match_id : YZgWW4m1
# padding : 44 for match_id : AT84VDeD
# padding : 39 for match_id : GxzdWteS
# padding : 43 for match_id : Mw3ImrQ2
# padding : 39 for match_id : dtNQSRmE
# padding : 55 for match_id : QXA4yudp
# padding : 44 for match_id : CQUTssJG
# padding : 53 for match_id : 8UJATjb6
# padding : 43 for match_id : 6yfgdkig
# padding : 40 for match_id : pnmt0sIP
# padding : 40 for match_id : SbheTgkA
# padding : 50 for match_id : vBgQBLXd
# padding : 44 for match_id : tK91N0Um
# padding : 41 for match_id : KrQtQ41f
# padding : 38 for match_id : YLCZrawr
# padding : 56 for match_id : vaVH0qHs
# padding : 45 for match_id : hh0ErhTd
# padding : 49 for match_id : EsJkOrW6
# padding : 45 for match_id : KODrVYbc
# padding : 41 for match_id : 61ReQADS
# padding : 48 for match_id : E7lNtWc9
# padding : 49 for match_id : UmOUcs10
# padding : 52 for match_id : Mm4DYQXl
# padding : 47 for match_id : CvSiRjbM
# padding : 40 for match_id : YDCv1fpH
# padding : 49 for match_id : I94PJONJ
# padding : 43 for match_id : EssbYSgE
# padding : 49 for match_id : QshRujDF
# padding : 51 for match_id : fXzQsVA2
# padding : 46 for match_id : WxEk7ovE
# padding : 42 for match_id : EXXDFgaA
# padding : 43 for match_id : MmfCAP17
# padding : 42 for match_id : nPfeE2os
# padding : 44 for match_id : tKZ5HFUc
# padding : 40 for match_id : C4Br0EaN
# padding : 48 for match_id : rHXfo4Hf
# padding : 46 for match_id : phtcJy0o
# padding : 46 for match_id : bejZwUsS
# padding : 46 for match_id : WraIsCr3
# padding : 46 for match_id : 8AL3E72r
# padding : 42 for match_id : 0vgG9qHD
# padding : 40 for match_id : KAY9GZq4
# padding : 44 for match_id : tUnrJoY1
# padding : 43 for match_id : YXvQCiqT
# padding : 44 for match_id : QmDz2zVA
# padding : 44 for match_id : 6L9vWEqi
# padding : 65 for match_id : OClCgS9E
# padding : 54 for match_id : 4x7WJ8jd
# padding : 53 for match_id : 8vNYd1G6
# padding : 41 for match_id : CIMYRQWs
# padding : 42 for match_id : 4GVe7V6j
# padding : 50 for match_id : fRNFB5n1
# padding : 35 for match_id : K4iVvASL
# padding : 61 for match_id : xGStvmAR
# padding : 46 for match_id : A9z7W6OQ
# padding : 48 for match_id : QPWi8Bip
# padding : 58 for match_id : 4WL3qrn7
# padding : 48 for match_id : YmTmSWrG
# padding : 44 for match_id : Spo2Xn9K
# padding : 44 for match_id : ncEW2GF4
# padding : 38 for match_id : fstMDXTM
# padding : 49 for match_id : rNINLULq
# padding : 63 for match_id : IZP7r21D
# padding : 39 for match_id : UD7LW421
# padding : 52 for match_id : 2wlvKRIe
# padding : 85 for match_id : fw2inYeF
# padding : 71 for match_id : GjBtQsuD
# padding : 52 for match_id : A1YpEctt
# padding : 58 for match_id : bX34oIa6
# padding : 45 for match_id : KQ65FwnS
# padding : 53 for match_id : OdChZXx1
# padding : 55 for match_id : AkhmeFaK
# padding : 51 for match_id : ERd60eJ9
# padding : 49 for match_id : 4dFFwYBd
# padding : 66 for match_id : xSrmpejQ
# padding : 46 for match_id : OhnyrPEs
# padding : 54 for match_id : hCMWKf2O
# padding : 61 for match_id : bNOswxkK
# padding : 67 for match_id : 82PUpHTE
# padding : 74 for match_id : 0xdgYBEC
# padding : 60 for match_id : pYyKXf3B
# padding : 68 for match_id : pOYeqbg3
# padding : 59 for match_id : KGNmCh0f
# padding : 50 for match_id : CzGdT5hq
# padding : 60 for match_id : ldF48AaJ
# padding : 56 for match_id : WKvMLgs4
# padding : 51 for match_id : Kftl5wMq
# padding : 65 for match_id : ze449r4f
# padding : 52 for match_id : UF2lwTtr
# padding : 62 for match_id : UeCM3FMB
# padding : 71 for match_id : lCkIAabM
# padding : 49 for match_id : Mk9dtLOm
# padding : 80 for match_id : Mogbady3
# padding : 82 for match_id : IH2XCHAn
# padding : 68 for match_id : 86iYJ3ns
# padding : 91 for match_id : MFxQV6p0
# padding : 48 for match_id : nH2XSbVB
# padding : 80 for match_id : GAT4yWHE
# padding : 57 for match_id : CblkGLo6
# padding : 46 for match_id : C6bibY7U
# padding : 104 for match_id : zsqrvVxK
# padding : 72 for match_id : xnRkotot
# padding : 82 for match_id : tOHqPeTp
# padding : 82 for match_id : 8YDVBixU
# padding : 69 for match_id : rRS5He8h
# padding : 61 for match_id : AyJKil7J
# padding : 62 for match_id : IqLIEghB
# padding : 62 for match_id : Ysdx8ryd
# padding : 48 for match_id : jk9OUK0a
# padding : 46 for match_id : vLdY8OLk
# padding : 59 for match_id : rVQYTpFC
# padding : 59 for match_id : WSEu72j2
# padding : 55 for match_id : YDxbEaGI
# padding : 69 for match_id : pKv0RWyH
# padding : 66 for match_id : O2T1rvVb
# padding : 79 for match_id : C6KMDD7H
# padding : 95 for match_id : llPIXSFm
# padding : 76 for match_id : IyBGWtWn
# padding : 66 for match_id : 06yUUQa6
# padding : 47 for match_id : 00GBXMGt
# padding : 91 for match_id : dWaWnaLi
# padding : 36 for match_id : xUDbHOth
# padding : 48 for match_id : O2LWN9ie
# padding : 38 for match_id : Ysb6T39r
# padding : 40 for match_id : 6TepAHc0
# padding : 52 for match_id : bPuh48sN
# padding : 64 for match_id : Eu0llfcn
# padding : 92 for match_id : KhmRlbze
# padding : 74 for match_id : zk1pkzrt
# padding : 43 for match_id : OQgIjK5r
# padding : 43 for match_id : 2HhMkvLl
# padding : 77 for match_id : 8SO0EoZ3
# padding : 65 for match_id : bgooVysb
# padding : 41 for match_id : x6LPktI5
# padding : 36 for match_id : AX25RE0b
# padding : 37 for match_id : MD1ag9XH
# padding : 39 for match_id : 6B2uiPxU
# padding : 36 for match_id : 2wl2Q4Sd
# padding : 49 for match_id : G6Rp4LPg
# padding : 49 for match_id : d2dSJBxU
# padding : 45 for match_id : GITMmhMt
# padding : 39 for match_id : fk44y1N3
# padding : 39 for match_id : bu6TC5fG
# padding : 41 for match_id : 8YuNONwb
# padding : 52 for match_id : KQ2mEsMn
# padding : 50 for match_id : UwNnKrt0
# padding : 41 for match_id : tUMXRgC0
# padding : 62 for match_id : AZuyhmVT
# padding : 38 for match_id : EZp0yk43
# padding : 46 for match_id : SQhjM3t9
# padding : 44 for match_id : tflKeVV4
# padding : 52 for match_id : f56udb9K
# padding : 48 for match_id : zV6NNVZ3
# padding : 34 for match_id : QsIlsoZ1
# padding : 64 for match_id : xIZI5Mfp
# padding : 50 for match_id : Wd0WL94G
# padding : 41 for match_id : 6ZrmBrXM
# padding : 42 for match_id : QNV3anY2
# padding : 45 for match_id : 2337z00Q
# padding : 41 for match_id : QiPRlvoe
# padding : 46 for match_id : CKRa0SId
# padding : 47 for match_id : Uoq3UDGk
# padding : 68 for match_id : GMPYARE7
# padding : 43 for match_id : UBbvfocG
# padding : 73 for match_id : OhbF9fNq
# padding : 39 for match_id : ObugiyO2
# padding : 49 for match_id : KfMJj0Gr
# padding : 45 for match_id : bHX5lZ7L
# padding : 59 for match_id : nsYHE9Fr
# padding : 55 for match_id : hvX9mgNR
# padding : 50 for match_id : CODtrXpk
# padding : 50 for match_id : CAY7TXVe
# padding : 46 for match_id : jepaVg1q
# padding : 84 for match_id : UgapefQp
# padding : 41 for match_id : voWDl1aJ
# padding : 33 for match_id : E3bEW3ND
# padding : 42 for match_id : 4Ij7eGL2
# padding : 40 for match_id : lf2PIIAj
# padding : 35 for match_id : 2T677Yap
# padding : 45 for match_id : 67lG5rfG
# padding : 38 for match_id : tYEeoKks
# padding : 42 for match_id : W4QXCrU8
# padding : 43 for match_id : QRPyC2qF
# padding : 70 for match_id : t2f32oIe
# padding : 55 for match_id : lAG5ENzA
# padding : 43 for match_id : Mk7BBqd2
# padding : 45 for match_id : fT0YguWA
# padding : 40 for match_id : zNSDew5B
# padding : 44 for match_id : hWYOMZhl
# padding : 47 for match_id : 8Cz87qrK
# padding : 38 for match_id : IJaV6Nx4
# padding : 37 for match_id : zeAQ73Nc
# padding : 73 for match_id : 2ZZB63cQ
# padding : 46 for match_id : OK6M8q8i
# padding : 73 for match_id : MJGr1sLm
# padding : 68 for match_id : butlW6ij
# padding : 47 for match_id : 4z2s4LMM
# padding : 46 for match_id : Qq3w517G
# padding : 48 for match_id : dAbZ5shA
# padding : 94 for match_id : 8OvA4Ibi
# padding : 74 for match_id : GjZpNNAm
# padding : 45 for match_id : prscPr8g
# padding : 39 for match_id : Mgc5wiup
# padding : 50 for match_id : tlkemcls
# padding : 33 for match_id : AyogGTJb
# padding : 50 for match_id : Yo8sO8r7
# padding : 69 for match_id : tbOaCdR4
# padding : 48 for match_id : CO7f7fWP
# padding : 64 for match_id : pr13egwi
# padding : 45 for match_id : fX8LofeK
# padding : 47 for match_id : n7Dd6oRl
# padding : 69 for match_id : G8lGlLML
# padding : 52 for match_id : 0pYq7OeK
# padding : 49 for match_id : jFCOatlf
# padding : 53 for match_id : 6oigp1l7
# padding : 60 for match_id : UaOF12Js
# padding : 74 for match_id : ddDPJXxI
# padding : 45 for match_id : CODK0MYm
# padding : 62 for match_id : MgZu84tE
# padding : 35 for match_id : On1GKtZj
# padding : 34 for match_id : QopjkQuD
# padding : 38 for match_id : SKmDj5Zn
# padding : 41 for match_id : GEFxH2wp
# padding : 42 for match_id : dUOKwMN1
# padding : 51 for match_id : rBbcuQuN
# padding : 37 for match_id : l0wBN5ws
# padding : 39 for match_id : IawwC5Fh
# padding : 37 for match_id : 8MHDWDPH
# padding : 50 for match_id : nopGeVCL
# padding : 40 for match_id : KKLv1HVH
# padding : 40 for match_id : h6JpGmyM
# padding : 37 for match_id : 6q8ISLVC
# padding : 44 for match_id : MmlpLXe7
# padding : 58 for match_id : fNFUv4rg
# padding : 32 for match_id : MqnRwOca
# padding : 37 for match_id : SfEMAmAR
# padding : 44 for match_id : rqnCMMSO
# padding : 40 for match_id : 0zoVxrD5
# padding : 44 for match_id : KbvRudW0
# padding : 43 for match_id : GWGQupTn
# padding : 38 for match_id : plQfo65P
# padding : 47 for match_id : zJr4OrbC
# padding : 36 for match_id : M9HMtQDt
# padding : 71 for match_id : CYzJsI1l
# padding : 49 for match_id : jRQD054j
# padding : 41 for match_id : fcpZy2SB
# padding : 45 for match_id : 6ezNtxHf
# padding : 45 for match_id : 4hm8N2DI
# padding : 44 for match_id : dSq0POr6
# padding : 41 for match_id : 2NTVvGo7
# padding : 65 for match_id : tpR1apef
# padding : 45 for match_id : AiTPPXkG
# padding : 52 for match_id : 4tN7bR39
# padding : 55 for match_id : GhpmutVi
# padding : 69 for match_id : nFJLzfyM
# padding : 43 for match_id : bHZiv0pb
# padding : 56 for match_id : x8YewKa4
# padding : 50 for match_id : jFh1Hxwo
# padding : 35 for match_id : xYNGJwSg
# padding : 36 for match_id : tQKJSgu8
# padding : 35 for match_id : 4dBtlhLT
# padding : 34 for match_id : 86esffI7
# padding : 38 for match_id : zFlITnY7
# padding : 38 for match_id : zN6MRrzm
# padding : 40 for match_id : St9oe6SK
# padding : 42 for match_id : 00WIfZar
# padding : 33 for match_id : UwByxmXQ
# padding : 40 for match_id : rg1BFNeT
# padding : 40 for match_id : tbnQ5NOB
# padding : 42 for match_id : tMlaxts0
# padding : 39 for match_id : OxML0Agq
# padding : 40 for match_id : KSDi8Uzs
# padding : 40 for match_id : lAYFCmgH
# padding : 43 for match_id : xEPRjwyN
# padding : 42 for match_id : tnWIha6A
# padding : 44 for match_id : pxfWgipI
# padding : 48 for match_id : WYkSfXUB
# padding : 41 for match_id : vagzgBaO
# padding : 46 for match_id : WUT0pyEj
# padding : 37 for match_id : lA0NeDF5
# padding : 42 for match_id : G4OVkcjT
# padding : 46 for match_id : KU86aeGt
# padding : 45 for match_id : YqBcoHbp
# padding : 40 for match_id : bi8EsCWR
# padding : 50 for match_id : CYUQWFZ6
# padding : 43 for match_id : ML17UzH6
# padding : 46 for match_id : jejzVyFP
# padding : 88 for match_id : h4x2QeNt
# padding : 40 for match_id : GObp8E7C
# padding : 39 for match_id : drdBzZ35
# padding : 38 for match_id : URvvRSu8
# padding : 40 for match_id : 0EL6ezO3
# padding : 44 for match_id : YiuxWZ6T
# padding : 43 for match_id : SAdZnwj2
# padding : 39 for match_id : rBv1htWD
# padding : 38 for match_id : OhUgUsP8
# padding : 42 for match_id : zJUY1gQd
# padding : 36 for match_id : jgstKpGM
# padding : 44 for match_id : UgaYhqEU
# padding : 42 for match_id : jPuZ8TG4
# padding : 48 for match_id : IDd8gCAI
# padding : 51 for match_id : 0nVePQHp
# padding : 46 for match_id : A1j3qm48
# padding : 49 for match_id : tt1N6H36
# padding : 42 for match_id : v3XcoTj1
# padding : 41 for match_id : C096Aa4s
# padding : 48 for match_id : KQCE8wZg
# padding : 48 for match_id : 2k2J7cl0
# padding : 49 for match_id : p4vkmkMl
# padding : 40 for match_id : Uu6sGLtK
# padding : 53 for match_id : IgW1pm67
# padding : 41 for match_id : AiNvFudQ
# padding : 75 for match_id : K8qcCEuB
# padding : 48 for match_id : K4afjy2S
# padding : 67 for match_id : 2ygqKqOG
# padding : 70 for match_id : lYluLP8A
# padding : 50 for match_id : lfvVuKO9
# padding : 45 for match_id : Kv6TRV7D
# padding : 46 for match_id : 4US86fG0
# padding : 48 for match_id : jV0vZ8QO
# padding : 36 for match_id : Sv42mQib
# padding : 42 for match_id : Y3cwTDS4
# padding : 52 for match_id : AFgkwMfa
# padding : 54 for match_id : hv7HKxk6
# padding : 43 for match_id : G4nfznx1
# padding : 42 for match_id : zc1YOn94
# padding : 41 for match_id : jNEJV1FR
# padding : 46 for match_id : ENGNZZsR
# padding : 49 for match_id : 23gjt7NJ
# padding : 51 for match_id : EevZ769p
# padding : 52 for match_id : IZ9Wguef
# padding : 43 for match_id : KbUe0sIQ
# padding : 46 for match_id : n9EzgaA0
# padding : 38 for match_id : QaDvhJP6
# padding : 55 for match_id : YcQ4PYvI
# padding : 71 for match_id : vqBSfLul
# padding : 55 for match_id : IZoQ5cB3
# padding : 58 for match_id : UiAu1TQR
# padding : 51 for match_id : WxjU4HQ9
# padding : 49 for match_id : Wn58z4Z6
# padding : 63 for match_id : bgcfb7RD
# padding : 56 for match_id : tWkOvJQh
# padding : 38 for match_id : AJPdZR7P
# padding : 42 for match_id : z9curfTo
# padding : 42 for match_id : 0GfM6En7
# padding : 43 for match_id : hhE3gkf0
# padding : 45 for match_id : hvmVOOWI
# padding : 47 for match_id : ryO3sIz1
# padding : 49 for match_id : MyCJk5WD
# padding : 43 for match_id : xlKBQcco
# padding : 46 for match_id : S4ZgzPXu
# padding : 45 for match_id : lx1tBT5K
# padding : 46 for match_id : df23MooU
# padding : 42 for match_id : 2yFtf559
# padding : 43 for match_id : 8zXBDsRl
# padding : 46 for match_id : boHKhnYO
# padding : 54 for match_id : raM1GF6k
# padding : 49 for match_id : 4MGEX2IK
# padding : 49 for match_id : juzGlhSu
# padding : 39 for match_id : 2uJNG96t
# padding : 54 for match_id : lWTIA7t4
# padding : 44 for match_id : xERaqVK3
# padding : 47 for match_id : U3OaE2fo
# padding : 42 for match_id : hjJGKSVk
# padding : 46 for match_id : 4UEmg4RG
# padding : 41 for match_id : GnLuqldH
# padding : 57 for match_id : 042dF3JT
# padding : 54 for match_id : vVX6Z64o
# padding : 43 for match_id : zHyLzdBk
# padding : 58 for match_id : UBMzd6sb
# padding : 50 for match_id : jRAqfpCA
# padding : 59 for match_id : 82LveQd4
# padding : 47 for match_id : GShIZFQe
# padding : 54 for match_id : 8Mu4cJI2
# padding : 38 for match_id : 8GS8O4fg
# padding : 34 for match_id : zqzT0ZRk
# padding : 42 for match_id : CC1BvxUF
# padding : 37 for match_id : hpn1KG9B
# padding : 41 for match_id : bcwuRzpA
# padding : 45 for match_id : l6Ov2TAs
# padding : 38 for match_id : MDDHicaR
# padding : 47 for match_id : volFFxBJ
# padding : 45 for match_id : EyxX6RAh
# padding : 33 for match_id : ART7L4wA
# padding : 39 for match_id : zgJTG56K
# padding : 46 for match_id : CGTUYD1g
# padding : 39 for match_id : QRTfHhUD
# padding : 46 for match_id : OWACuo2p
# padding : 38 for match_id : WOW5kPuo
# padding : 43 for match_id : zBCxDZji
# padding : 47 for match_id : vRiRd7mB
# padding : 45 for match_id : WGxsE8Io
# padding : 49 for match_id : UFpvf5XT
# padding : 44 for match_id : A7yoDSXi
# padding : 52 for match_id : 0zgNcmY4
# padding : 61 for match_id : 6THFhA9i
# padding : 44 for match_id : StR4WJhk
# padding : 42 for match_id : W4ChVl3j
# padding : 76 for match_id : hEDlWUmp
# padding : 54 for match_id : v7XDxXAG
# padding : 60 for match_id : KQlqhCA3
# padding : 58 for match_id : YTWHyiQM
# padding : 34 for match_id : reKF2lua
# padding : 45 for match_id : UTee4uuE
# padding : 34 for match_id : l2dZFs3n
# padding : 38 for match_id : ngbtInEQ
# padding : 43 for match_id : xbkopa3C
# padding : 43 for match_id : vaVzxDZI
# padding : 42 for match_id : r1BqTZzr
# padding : 54 for match_id : GfgY25SR
# padding : 45 for match_id : 4IOuBMbL
# padding : 75 for match_id : Qs0wWYbE
# padding : 44 for match_id : t4ZJOuTK
# padding : 55 for match_id : p8jAPHJi
# padding : 41 for match_id : YJ7UDOE2
# padding : 49 for match_id : QkvF29Er
# padding : 57 for match_id : tIKYgdGC
# padding : 46 for match_id : YiLUfx16
# padding : 65 for match_id : nq9EPkY8
# padding : 47 for match_id : MDcLHa8J
# padding : 78 for match_id : E5uBO9mF
# padding : 62 for match_id : WnmeBcom
# padding : 58 for match_id : hdliCwWt
# padding : 65 for match_id : IHOggPP1
# padding : 34 for match_id : x2ZANAJS
# padding : 41 for match_id : jmOFKVC1
# padding : 47 for match_id : 06D1UWMq
# padding : 40 for match_id : YX2eQPUl
# padding : 37 for match_id : hAuhJBIc
# padding : 48 for match_id : OUao1BEl
# padding : 50 for match_id : U5kedWcI
# padding : 38 for match_id : vg6EAFaT
# padding : 39 for match_id : tMSqQfaG
# padding : 51 for match_id : hn7fLx5R
# padding : 40 for match_id : r1oitvxC
# padding : 49 for match_id : EmSehDr9
# padding : 44 for match_id : jXZWSdFc
# padding : 43 for match_id : jsXe1NvU
# padding : 66 for match_id : zTabOuTn
# padding : 53 for match_id : 6LZTanNA
# padding : 44 for match_id : URWy7vbC
# padding : 48 for match_id : OlWu6bDI
# padding : 51 for match_id : vcEST15P
# padding : 50 for match_id : GOSX7Kr6
# padding : 34 for match_id : YawT80Ta
# padding : 58 for match_id : GWtH2lwh
# padding : 43 for match_id : xnVP0S74
# padding : 47 for match_id : pCYXb6xH
# padding : 46 for match_id : 2B3lGryQ
# padding : 35 for match_id : nquLAMbm
# padding : 45 for match_id : xzZyjnNK
# padding : 51 for match_id : buOjKlYS
# padding : 50 for match_id : tAdB7Pvf
# padding : 59 for match_id : OYoG6qf0
# padding : 58 for match_id : WbkO4NOC
# padding : 40 for match_id : M7WbpOW0
# padding : 37 for match_id : KIvzDrgI
# padding : 37 for match_id : CtiVtkAM
# padding : 40 for match_id : na5paaI6
# padding : 43 for match_id : db8BabRn
# padding : 47 for match_id : S6Ynihjl
# padding : 40 for match_id : fN9s1pxm
# padding : 38 for match_id : Ia7ibqlP
# padding : 50 for match_id : xnLpxVBf
# padding : 44 for match_id : ENSyEjxs
# padding : 55 for match_id : AuawJFA8
# padding : 49 for match_id : WhtSzvA6
# padding : 39 for match_id : 4MdnbEYr
# padding : 76 for match_id : IkxOyKf0
# padding : 38 for match_id : Or3sIZPE
# padding : 50 for match_id : xzefdh3e
# padding : 78 for match_id : MsyelC1s
# padding : 66 for match_id : 8C4QihUa
# padding : 36 for match_id : vqH8eRpJ
# padding : 42 for match_id : ll3aVXbH
# padding : 41 for match_id : nTKqrmIf
# padding : 35 for match_id : AVonLe7S
# padding : 45 for match_id : C2v95gjJ
# padding : 45 for match_id : KhaJB0xC
# padding : 35 for match_id : rDikknPs
# padding : 46 for match_id : KzKUo1S2
# padding : 45 for match_id : 2yFL1dra
# padding : 41 for match_id : xYyoWXkU
# padding : 36 for match_id : 4WkNYSBC
# padding : 43 for match_id : jFroDtg5
# padding : 39 for match_id : Cj8l9vjP
# padding : 34 for match_id : MLwaSbJq
# padding : 44 for match_id : MqILWCX4
# padding : 43 for match_id : rsXxjUDE
# padding : 39 for match_id : xjHMiKJr
# padding : 38 for match_id : MkobTsWt
# padding : 49 for match_id : tQplA5DS
# padding : 46 for match_id : bHmGaifn
# padding : 43 for match_id : tvQMO4SL
# padding : 38 for match_id : 4KgTETbc
# padding : 41 for match_id : h828Tyu1
# padding : 42 for match_id : 8I1O7HOH
# padding : 40 for match_id : QcCti3u9
# padding : 38 for match_id : UHoi9ZOr
# padding : 37 for match_id : dIQp6qWF
# padding : 43 for match_id : ltsi4iy9
# padding : 38 for match_id : 8M1ojNfF
# padding : 43 for match_id : GIJd8Uzd
# padding : 37 for match_id : p0brUz18
# padding : 39 for match_id : riGE7raM
# padding : 44 for match_id : IwfcAaXg
# padding : 53 for match_id : 6u22FoFj
# padding : 44 for match_id : M7xQCnfo
# padding : 41 for match_id : xQX1zmiG
# padding : 43 for match_id : SK9tnAWo
# padding : 43 for match_id : z9TpLpMh
# padding : 42 for match_id : MVjbJ9YE
# padding : 51 for match_id : tjEtjFjO
# padding : 39 for match_id : fwzpUu5N
# padding : 43 for match_id : I77TnkvF
# padding : 43 for match_id : rmbaFWd0
# padding : 49 for match_id : xKbVIfuP
# padding : 39 for match_id : dbdk1txj
# padding : 41 for match_id : YBkNHdcA
# padding : 41 for match_id : CYEg4QA4
# padding : 39 for match_id : 8biMOC9o
# padding : 39 for match_id : bFlW5USP
# padding : 43 for match_id : rNKQ3ex5
# padding : 45 for match_id : QqeRcPFi
# padding : 47 for match_id : 8GdjHxF5
# padding : 41 for match_id : ShqaOSIe
# padding : 48 for match_id : Ob383Y2d
# padding : 39 for match_id : nmNmqwE4
# padding : 43 for match_id : GdlMUeq5
# padding : 37 for match_id : IFJyszKU
# padding : 40 for match_id : lSmyxTzr
# padding : 44 for match_id : IiRm2Cys
# padding : 41 for match_id : M3OzKqiT
# padding : 47 for match_id : lhigUCKg
# padding : 53 for match_id : SMbNTZ4U
# padding : 49 for match_id : Wf5EVezI
# padding : 52 for match_id : 0SfcTWZa
# padding : 46 for match_id : pv32Ycja
# padding : 41 for match_id : nPUNEXK6
# padding : 58 for match_id : 2ThWmwjn
# padding : 56 for match_id : 8YVJFD50
# padding : 50 for match_id : EcHGGgjf
# padding : 46 for match_id : h46AWyLB
# padding : 45 for match_id : GvgoWYks
# padding : 49 for match_id : rip2Sjk6
# padding : 55 for match_id : dfCEyeSJ
# padding : 46 for match_id : nLhuLmGr
# padding : 41 for match_id : hrDVECg9
# padding : 47 for match_id : zoBIzFsQ
# padding : 54 for match_id : z7ICHZzl
# padding : 51 for match_id : rDiA7Uoq
# padding : 54 for match_id : fVikVh5m
# padding : 39 for match_id : xWEsCAwS
# padding : 44 for match_id : fodmJRpe
# padding : 42 for match_id : QeBwDjOL
# padding : 64 for match_id : WYBZDW8F
# padding : 45 for match_id : WdrTYBZd
# padding : 66 for match_id : QyRcqZBM
# padding : 49 for match_id : tdsm9aP8
# padding : 44 for match_id : WOMa2vaI
# padding : 55 for match_id : zwR9zAhB
# padding : 49 for match_id : UJQSQOjB
# padding : 65 for match_id : EBKH8ooB
# padding : 79 for match_id : jTkbKwOt
# padding : 44 for match_id : dUxDGdkP
# padding : 55 for match_id : 4SBWfxpm
# padding : 49 for match_id : jP7SeIUt
# padding : 67 for match_id : 4U28jNh1
# padding : 67 for match_id : xtAvgGEa
# padding : 59 for match_id : bkBzfdag
# padding : 60 for match_id : AV9ahqOl
# padding : 45 for match_id : A7RC1m12
# padding : 46 for match_id : hOMVDHjP
# padding : 44 for match_id : xGvqjEbI
# padding : 77 for match_id : 42tyhzU5
# padding : 49 for match_id : fX8c9yat
# padding : 55 for match_id : dOTObooL
# padding : 34 for match_id : l81rCxw4
# padding : 34 for match_id : OWEGoAlg
# padding : 33 for match_id : AoxSVvf9
# padding : 35 for match_id : UVlQ3sND
# padding : 37 for match_id : zVY3j4fs
# padding : 33 for match_id : QiuaHF93
# padding : 35 for match_id : 6D5Rk9aO
# padding : 42 for match_id : xfHlW3O1
# padding : 38 for match_id : 0IeXUtFL
# padding : 37 for match_id : 6FQcHx3C
# padding : 34 for match_id : lOF1SWof
# padding : 41 for match_id : WURDopYt
# padding : 36 for match_id : dhe6ZiKB
# padding : 32 for match_id : 0rPz6Pfj
# padding : 43 for match_id : bPo1R7j2
# padding : 42 for match_id : zeSkMFtQ
# padding : 38 for match_id : GSzRADoQ
# padding : 34 for match_id : OfTXdOqt
# padding : 45 for match_id : 2ZPVNFXd
# padding : 38 for match_id : pthIFxNn
# padding : 32 for match_id : hdCLZp1C
# padding : 34 for match_id : ltLYs5a9
# padding : 34 for match_id : xWYcJxuq
# padding : 42 for match_id : QBJ7dIlS
# padding : 34 for match_id : 2czJ1DDt
# padding : 39 for match_id : tr88Akpb
# padding : 42 for match_id : Q9bEedgC
# padding : 41 for match_id : ji0NNTfe
# padding : 39 for match_id : d60wwYEG
# padding : 41 for match_id : WCQHmSxo
# padding : 38 for match_id : pMDz5GTL
# padding : 36 for match_id : ANyfsm62
# padding : 45 for match_id : Slak3ojd
# padding : 55 for match_id : jaEW5dEF
# padding : 34 for match_id : lEzbt7L8
# padding : 40 for match_id : GtMJ8bUd
# padding : 43 for match_id : IF1ZwEaA
# padding : 49 for match_id : 2PIxpFid
# padding : 39 for match_id : 46f7afiq
# padding : 44 for match_id : Oh2Vvfp4
# padding : 37 for match_id : 8IcBI3T1
# padding : 35 for match_id : SQ8MtGFi
# padding : 33 for match_id : OYJYpexj
# padding : 38 for match_id : xdAS6xa9
# padding : 47 for match_id : 8IJtYrTl
# padding : 43 for match_id : dvv6vojL
# padding : 44 for match_id : fXKN7Iq3
# padding : 35 for match_id : fFg7JqEe
# padding : 37 for match_id : Imu2uRzF
# padding : 44 for match_id : M1eaL5qq
# padding : 43 for match_id : 0hf3KPbk
# padding : 42 for match_id : v3TAw55R
# padding : 41 for match_id : AkbRuzVc
# padding : 48 for match_id : hpAH2NVe
# padding : 46 for match_id : h44C4Urg
# padding : 43 for match_id : CdVWbWbA
# padding : 36 for match_id : 4pHGPyKP
# padding : 43 for match_id : llZ8QWM9
# padding : 45 for match_id : KIrTuCgO
# padding : 47 for match_id : E9PgKfYG
# padding : 57 for match_id : 06aK5eJN
# padding : 71 for match_id : nqcXyXCP
# padding : 47 for match_id : hptGT8K5
# padding : 41 for match_id : z9VKSSZB
# padding : 39 for match_id : Yu9kDmzP
# padding : 46 for match_id : 6FbVHBLg
# padding : 48 for match_id : p6cZGVz0
# padding : 44 for match_id : Oj9QIi6m
# padding : 63 for match_id : Eu2wGkj6
# padding : 49 for match_id : lhqaXjLt
# padding : 44 for match_id : pKx8VUkg
# padding : 49 for match_id : vsxCUl5a
# padding : 56 for match_id : CUdykCxF
# padding : 57 for match_id : 6Tw4WAzm
# padding : 46 for match_id : dUfjj1mC
# padding : 48 for match_id : ETsDC8ZF
# padding : 49 for match_id : OtEYZsWm
# padding : 44 for match_id : OKUSkjaj
# padding : 46 for match_id : dGckaoJK
# padding : 54 for match_id : 21niQStt
# padding : 48 for match_id : lKHPgAOi
# padding : 44 for match_id : W4nd9LSB
# padding : 41 for match_id : vJLmQ4Xh
# padding : 50 for match_id : EosHb9Jf
# padding : 47 for match_id : IieVvYZg
# padding : 48 for match_id : 4E2ogEtT
# padding : 50 for match_id : be8vnKBl
# padding : 53 for match_id : M3vrJmQP
# padding : 49 for match_id : xxUMplvp
# padding : 43 for match_id : p2XUrS8d
# padding : 56 for match_id : 0Eu2mDul
# padding : 47 for match_id : fHQcjAGM
# padding : 57 for match_id : QcAH6V03
# padding : 51 for match_id : GQRgij1G
# padding : 54 for match_id : IkjclgQs
# padding : 48 for match_id : zTsekUVS
# padding : 51 for match_id : pG6ftKHL
# padding : 70 for match_id : 2aiNHQB4
# padding : 69 for match_id : vu7E0qat
# padding : 50 for match_id : EFSGU4o2
# padding : 60 for match_id : 2HtBG6UR
# padding : 71 for match_id : UkT3ISaF
# padding : 67 for match_id : 8tS7HnFL
# padding : 71 for match_id : nkIsBphk
# padding : 47 for match_id : nRwaJ8p9
# padding : 41 for match_id : dYpF0bum
# padding : 37 for match_id : MBvPPms8
# padding : 41 for match_id : CGud6qti
# padding : 38 for match_id : zqnokhsJ
# padding : 43 for match_id : WKd8B20Q
# padding : 40 for match_id : jwXXMGoD
# padding : 42 for match_id : nXbO9oco
# padding : 37 for match_id : SY8N67k5
# padding : 41 for match_id : QRotTgPB
# padding : 38 for match_id : zgsBqSCb
# padding : 44 for match_id : pn1ExpVQ
# padding : 41 for match_id : UeYSQnWE
# padding : 43 for match_id : x0Yf5P60
# padding : 44 for match_id : by85Xmk0
# padding : 36 for match_id : 6JrJnKf4
# padding : 38 for match_id : 6ZYIM6MA
# padding : 36 for match_id : rs5qY8xc
# padding : 41 for match_id : S43Xv54f
# padding : 43 for match_id : xr7KLgkJ
# padding : 41 for match_id : xCdz48q0
# padding : 39 for match_id : pxIEAtfO
# padding : 47 for match_id : Cjllm8uH
# padding : 41 for match_id : GvRH3rN1
# padding : 42 for match_id : 6gk0iAoq
# padding : 42 for match_id : 8jir9JHU
# padding : 39 for match_id : OMonlTLa
# padding : 47 for match_id : ruW2LqDU
# padding : 46 for match_id : QFTTmuqE
# padding : 46 for match_id : 2PpudjwS
# padding : 51 for match_id : 0lE7bbHG
# padding : 47 for match_id : Ol4NNul5
# padding : 43 for match_id : f1vBB47A
# padding : 51 for match_id : rD3CcIWM
# padding : 43 for match_id : v3aPb7Ba
# padding : 33 for match_id : WngLd082
# padding : 36 for match_id : lWZtBIl9
# padding : 43 for match_id : AXGxTw7l
# padding : 37 for match_id : 4nbAkrHl
# padding : 43 for match_id : b32aoqYp
# padding : 54 for match_id : dtyqZMW7
# padding : 45 for match_id : Qgzi1OVb
# padding : 52 for match_id : tb0tRq7c
# padding : 42 for match_id : QkIg3tFj
# padding : 56 for match_id : AVPPB6s8
# padding : 48 for match_id : GGSJ9rxN
# padding : 41 for match_id : S2vYzkB2
# padding : 38 for match_id : Qie7DZms
# padding : 46 for match_id : YHbFBDIg
# padding : 48 for match_id : WKQGQThT
# padding : 50 for match_id : 4IYaVakU
# padding : 45 for match_id : QVsIRP8i
# padding : 44 for match_id : fcAN16nI
# padding : 48 for match_id : YwhLPO21
# padding : 45 for match_id : t4wbMUWB
# padding : 46 for match_id : bBddWGUk
# padding : 55 for match_id : nw8ZFtSI
# padding : 56 for match_id : YiFjAHf4
# padding : 48 for match_id : z9LIhsw7
# padding : 44 for match_id : ldcsskwA
# padding : 53 for match_id : Mq6Deqgl
# padding : 46 for match_id : 0hjW3MGp
# padding : 44 for match_id : jDNevIAm
# padding : 41 for match_id : bwR3xdu0
# padding : 51 for match_id : CUYgNAH5
# padding : 46 for match_id : MqfHMFK7
# padding : 44 for match_id : nNTCGa0j
# padding : 46 for match_id : hxKCzzAC
# padding : 51 for match_id : 2cjW7VHI
# padding : 45 for match_id : xCtsQCXn
# padding : 51 for match_id : QDSGFJFd
# padding : 42 for match_id : lMOTAQdE
# padding : 41 for match_id : 8ziS8B2C
# padding : 44 for match_id : KnSawxQg
# padding : 41 for match_id : Cn8rELdr
# padding : 54 for match_id : 06ZWyp6n
# padding : 60 for match_id : vZgwMzeJ
# padding : 46 for match_id : n50eBJt1
# padding : 48 for match_id : KAIvIFuQ
# padding : 75 for match_id : jwTsMLxT
# padding : 58 for match_id : trIbTCJq
# padding : 63 for match_id : rkswRhIt
# padding : 47 for match_id : jFUeWuzO
# padding : 44 for match_id : YwzjOj2a
# padding : 52 for match_id : tteBVY9P
# padding : 52 for match_id : tlkz7kXO
# padding : 53 for match_id : K8ekX03K
# padding : 51 for match_id : KjpFVmSF
# padding : 45 for match_id : Kfx2LlnI
# padding : 63 for match_id : UogcOBJd
# padding : 47 for match_id : jw7nDuCl
# padding : 46 for match_id : 4zl1s6rP
# padding : 48 for match_id : jFpoPWng
# padding : 49 for match_id : hxrLpKXJ
# padding : 44 for match_id : KWwxOdQ6
# padding : 59 for match_id : 6mtBWTC9
# padding : 66 for match_id : vDI29cBD
# padding : 53 for match_id : lr0gWKIQ
# padding : 46 for match_id : KGHzPlZ0
# padding : 50 for match_id : tSaaAwd7
# padding : 49 for match_id : MT7LDRsH
# padding : 50 for match_id : 8E1iCaRf
# padding : 42 for match_id : Gd2Ims5b
# padding : 61 for match_id : zPRqZsj5
# padding : 43 for match_id : 6unPqvmQ
# padding : 49 for match_id : 0reZMGuD
# padding : 57 for match_id : UatmY15B
# padding : 38 for match_id : naJGZgPI
# padding : 50 for match_id : tIdoYtlE
# padding : 77 for match_id : QHtwiYkO
# padding : 62 for match_id : tvpicQJQ
# padding : 46 for match_id : WChCi1nC
# padding : 59 for match_id : pKrVVRtB
# padding : 49 for match_id : pdE6ronp
# padding : 50 for match_id : hMHEtPGd
# padding : 64 for match_id : jaEa8ZKb
# padding : 64 for match_id : 8QoqankE
# padding : 62 for match_id : AZmZjqEi
# padding : 61 for match_id : CUS9OqZp
# padding : 71 for match_id : YeJQikPc
# padding : 77 for match_id : KCwaV1CQ
# padding : 66 for match_id : 6TqRW7R4
# padding : 55 for match_id : 6aAcc3w4
# padding : 62 for match_id : 0IZvKjb2
# padding : 78 for match_id : IeBeCdUk
# padding : 62 for match_id : 4QvtvLyj
# padding : 99 for match_id : nXO6Hcx4
# padding : 56 for match_id : YNZOHI6S
# padding : 73 for match_id : reInXc6F
# padding : 53 for match_id : xMwkUzM9
# padding : 54 for match_id : 0zTAGHiA
# padding : 50 for match_id : IDOMewMK
# padding : 51 for match_id : pEc6A5d2
# padding : 97 for match_id : nZ15mFT0
# padding : 61 for match_id : IwCOVS8k
# padding : 70 for match_id : tUQtIQYi
# padding : 54 for match_id : ppS9KoQn
# padding : 79 for match_id : 4Y4Qidjq
# padding : 44 for match_id : KrhMs4WB
# padding : 73 for match_id : rPLSXS2m
# padding : 60 for match_id : tteEXvQ1
# padding : 64 for match_id : r3phLkJs
# padding : 61 for match_id : YTfIRitE
# padding : 81 for match_id : jk1UsPm9
# padding : 47 for match_id : I1GiSOWO
# padding : 78 for match_id : xpjZR0zc
# padding : 58 for match_id : KQ65Z0ek
# padding : 80 for match_id : 02Ded3o5
# padding : 60 for match_id : 00YyxZaj
# padding : 81 for match_id : jBx5f2XE
# padding : 52 for match_id : Aw2i3Hcd
# padding : 64 for match_id : fJazi89P
# padding : 54 for match_id : nHvFqQ1a
# padding : 64 for match_id : plIqUp2C
# padding : 76 for match_id : 6uEicqWb
# padding : 66 for match_id : jkPzW6Xa
# padding : 53 for match_id : 4YMOY8ms
# padding : 75 for match_id : vVw1JTmf
# padding : 51 for match_id : dSo2nSHt
# padding : 62 for match_id : C2rnPbKF
# ...
# padding : 58 for match_id : UFY1UoN9
# padding : 41 for match_id : zVYc5ApS
# padding : 54 for match_id : 0dzjgIs4
# padding : 42 for match_id : 8MgkW6c5
# padding : 39 for match_id : KKTYot1C
# padding : 37 for match_id : 8rqjhy2I
# padding : 44 for match_id : SY0fiD1I
# padding : 52 for match_id : 2XvDV2qO
# padding : 49 for match_id : SGmQOELH
# padding : 43 for match_id : jVjBxMS2
# padding : 38 for match_id : 4to2ne7l
# padding : 39 for match_id : MTTvuPZ3
# padding : 43 for match_id : 2HEAiMuF
# padding : 43 for match_id : jJMIfrb1
# padding : 37 for match_id : lvSXDQsl
# padding : 43 for match_id : 8bPwX5lQ
# padding : 51 for match_id : Eu26SPds
# padding : 57 for match_id : U7QZXoZJ
# padding : 42 for match_id : 8byt3crq
# padding : 47 for match_id : W2XSE6Ss
# padding : 34 for match_id : SUQyDpcf
# padding : 37 for match_id : zXocKS4K
# padding : 38 for match_id : jJlE7wzS
# padding : 64 for match_id : M1up2Hck
# padding : 43 for match_id : 21YmArsD
# padding : 39 for match_id : 4QUl1yDe
# padding : 46 for match_id : MiQuC4C0
# padding : 36 for match_id : Ugo1JnKQ
# padding : 52 for match_id : thXi92dJ
# padding : 44 for match_id : KxqqBOR6
# padding : 46 for match_id : 0GlrORCO
# padding : 51 for match_id : Gb5rIgoR
# padding : 46 for match_id : GrP5LSiJ
# padding : 71 for match_id : thT74l7b
# padding : 56 for match_id : dUfkn7iU
# padding : 72 for match_id : zeQa6Axn
# padding : 46 for match_id : tExDPF8o
# padding : 50 for match_id : tjzptSEd
# padding : 40 for match_id : 0txThduJ
# padding : 39 for match_id : bNxa874P
# padding : 41 for match_id : SYtqzI3R
# padding : 47 for match_id : OUcUQQwK
# padding : 45 for match_id : dGXRVCLG
# padding : 48 for match_id : l8LkmX24
# padding : 40 for match_id : n1Ufjv30
# padding : 47 for match_id : rFv1L41s
# padding : 46 for match_id : htSPXcuc
# padding : 41 for match_id : EcNpAfmj
# padding : 42 for match_id : KzUI22lG
# padding : 42 for match_id : G2NR0tJS
# padding : 46 for match_id : IB9gd0Rq
# padding : 50 for match_id : 0jsAGdAM
# padding : 41 for match_id : EZvbJbQ3
# padding : 52 for match_id : rFWEFGPS
# padding : 51 for match_id : KEnyLREj
# padding : 47 for match_id : 0G8dpYTQ
# padding : 49 for match_id : 0IydC3Qp
# padding : 44 for match_id : tYfPHP2N
# padding : 45 for match_id : SOTsz7Ii
# padding : 58 for match_id : lvIjYpm4
# padding : 31 for match_id : fDWAv69I
# padding : 35 for match_id : YyiWqkeB
# padding : 36 for match_id : 2eJfqxR5
# padding : 32 for match_id : EeOidK7C
# padding : 40 for match_id : zDZkuDEU
# padding : 42 for match_id : nXOLuFkE
# padding : 41 for match_id : IRuhaUMp
# padding : 32 for match_id : zuYSIeKd
# padding : 35 for match_id : 2TlDeT4d
# padding : 47 for match_id : xt0kcJnh
# padding : 47 for match_id : 8hbj7HXc
# padding : 39 for match_id : lfhU5zpo
# padding : 40 for match_id : QyckEqKE
# padding : 41 for match_id : ADxTes3f
# padding : 41 for match_id : Cd3sdVut
# padding : 34 for match_id : rg9JutLI
# padding : 49 for match_id : YuLbFq7D
# padding : 38 for match_id : 40Jwoycb
# padding : 42 for match_id : fkMfGPi7
# padding : 34 for match_id : YVJy6694
# padding : 43 for match_id : QmBXtpIo
# padding : 35 for match_id : I1WqdMMd
# padding : 42 for match_id : 0UJEtM5C
# padding : 45 for match_id : 2XCuMulB
# padding : 39 for match_id : phbpnqLF
# padding : 41 for match_id : EsozqLc4
# padding : 43 for match_id : AJ7NZnpA
# padding : 42 for match_id : 6ejhVD15
# padding : 67 for match_id : 27kx9kGa
# padding : 46 for match_id : EV6hwA0F
# padding : 50 for match_id : UZ8I7noB
# padding : 37 for match_id : nZThXoz7
# padding : 71 for match_id : IDYwKCtB
# padding : 54 for match_id : 0vssxjZq
# padding : 45 for match_id : tzKNvJsc
# padding : 39 for match_id : dCk1VnBE
# padding : 42 for match_id : p0zZJ8nl
# padding : 38 for match_id : rwyi4EHq
# padding : 42 for match_id : fPlMsaRl
# padding : 50 for match_id : WMgVZ4U3
# padding : 51 for match_id : W2oJLCXs
# padding : 45 for match_id : 6sFKBdP9
# padding : 41 for match_id : GroQF5lG
# padding : 38 for match_id : je2LGF9j
# padding : 62 for match_id : 8IchjyN6
# padding : 40 for match_id : GxtMbNRa
# padding : 43 for match_id : zgH1yXNb
# padding : 42 for match_id : 4SNQvYam
# padding : 39 for match_id : 63p8vJ1c
# padding : 72 for match_id : 08lE4GUf
# padding : 70 for match_id : 4x3DtVb9
# padding : 46 for match_id : MVtJciAs
# padding : 34 for match_id : r3zVBDfB
# padding : 46 for match_id : 65mLMU8T
# padding : 69 for match_id : YBJ9rPb0
# padding : 41 for match_id : nmsZ3F33
# padding : 35 for match_id : fHrxm1dM
# padding : 46 for match_id : j95DNPBD
# padding : 41 for match_id : 6RbA41C4
# padding : 46 for match_id : bXZAtvIh
# padding : 42 for match_id : CrAnwjgA
# padding : 38 for match_id : lUU8QciE
# padding : 58 for match_id : AJ7f27En
# padding : 57 for match_id : vyHO7TjP
# padding : 55 for match_id : QeZypQbI
# padding : 54 for match_id : 2grHllpm
# padding : 45 for match_id : tp3j3mat
# padding : 48 for match_id : dGsLm8ag
# padding : 42 for match_id : hryUonU5
# padding : 59 for match_id : 2k67tBi4
# padding : 80 for match_id : ILpxRViH
# padding : 47 for match_id : OboYRBxB
# padding : 45 for match_id : WYZXp6qC
# padding : 48 for match_id : xWxtqpEO
# padding : 50 for match_id : z7tPnSEa
# padding : 53 for match_id : GdQCKTUp
# padding : 71 for match_id : WOABuV6A
# padding : 41 for match_id : ddosCrrB
# padding : 46 for match_id : hvaKw9yN
# padding : 65 for match_id : tzIbrXMi
# padding : 43 for match_id : xhEGeNcU
# padding : 47 for match_id : AuqVEpbh
# padding : 80 for match_id : Ob73sixb
# padding : 52 for match_id : EDkMG6Tu
# padding : 45 for match_id : dCqtQk7N
# padding : 46 for match_id : lWsZD4Db
# padding : 38 for match_id : IkbFcqTH
# padding : 70 for match_id : EmvoP9MT
# padding : 45 for match_id : b1FCd3rO
# padding : 71 for match_id : px07a5b5
# padding : 42 for match_id : I5nwDOS4
# padding : 46 for match_id : SGgQFQrn
# padding : 68 for match_id : 08npYNSI
# padding : 100 for match_id : MHmtZ3DC
# padding : 60 for match_id : n3BaQY2L
# padding : 52 for match_id : 2HQTgmmH
# padding : 75 for match_id : bqKxhRHT
# padding : 80 for match_id : U3SLe9I4
# padding : 83 for match_id : YyZCcVmh
# padding : 43 for match_id : 0IaSSdzH
# padding : 44 for match_id : fPY1FHUR
# padding : 43 for match_id : Us9F9hcD
# padding : 42 for match_id : Ms1SyGc7
# padding : 47 for match_id : 4rYlvmN2
# padding : 63 for match_id : UXTrBkGf
# padding : 41 for match_id : lIjNwNA4
# padding : 47 for match_id : plMXG5UP
# padding : 46 for match_id : 4ApwLQqJ
# padding : 43 for match_id : zXHJzGSK
# padding : 36 for match_id : jBrpYKHq
# padding : 75 for match_id : IcxjswNA
# padding : 39 for match_id : jkgSNlMk
# padding : 55 for match_id : vuwrchac
# padding : 42 for match_id : E3lxOxqF
# padding : 43 for match_id : Iy9FjCm9
# padding : 44 for match_id : ChyjeWT9
# padding : 53 for match_id : nFkSen8i
# padding : 47 for match_id : Y1xndCE3
# padding : 51 for match_id : K81pX2Vj
# padding : 89 for match_id : l24BihY2
# padding : 58 for match_id : jXV1apQ3
# padding : 62 for match_id : bFQ5cK0g
# padding : 52 for match_id : nBi1cZIq
# padding : 46 for match_id : xxhlWqZ5
# padding : 49 for match_id : zNAiV3lC
# padding : 81 for match_id : n1vAmo4t
# padding : 39 for match_id : KASG3jz8
# padding : 33 for match_id : WxYSMZoE
# padding : 34 for match_id : jT7jkt8h
# padding : 37 for match_id : jRrt6Twq
# padding : 34 for match_id : vBZr4rxU
# padding : 44 for match_id : OYyX1Ntt
# padding : 36 for match_id : MZvv5OMN
# padding : 37 for match_id : SGqzuLkJ
# padding : 39 for match_id : htIIhQvg
# padding : 48 for match_id : C6MGAXd1
# padding : 33 for match_id : ltqAHE18
# padding : 46 for match_id : K0oGYfiD
# padding : 31 for match_id : rTJHQ5Jl
# padding : 44 for match_id : 08hyMlf5
# padding : 37 for match_id : 4lLN6C5t
# padding : 39 for match_id : 2NyazVTC
# padding : 40 for match_id : t8e1OO3j
# padding : 45 for match_id : p2TL6cX3
# padding : 39 for match_id : rFAZb9ZP
# padding : 41 for match_id : lGNqlBxL
# padding : 35 for match_id : ELg6OScD
# padding : 42 for match_id : n92kSAbl
# padding : 35 for match_id : O8Um5Vw9
# padding : 40 for match_id : UmhgBA95
# padding : 39 for match_id : 4vxB4wW0
# padding : 39 for match_id : bosYx31n
# padding : 38 for match_id : tEz3ZlqJ
# padding : 38 for match_id : tnQQpjCa
# padding : 46 for match_id : M3zewChA
# padding : 41 for match_id : CUzkU9cf
# padding : 47 for match_id : YsWgTnn0
# padding : 54 for match_id : ni3Ks9Fl
# padding : 38 for match_id : W0OCtRZA
# padding : 36 for match_id : tE2OtTUf
# padding : 43 for match_id : tAnN1U6K
# padding : 39 for match_id : KbIsU7Fd
# padding : 43 for match_id : ChT7zAxT
# padding : 45 for match_id : Qc44IVXs
# padding : 37 for match_id : j51GFTH0
# padding : 44 for match_id : UTw3yjNM
# padding : 42 for match_id : xzmSyKY2
# padding : 44 for match_id : WEmky7Kq
# padding : 34 for match_id : t8JwVm0j
# padding : 36 for match_id : nXfPD7nD
# padding : 41 for match_id : UZrJ2AiE
# padding : 41 for match_id : K41Sump1
# padding : 45 for match_id : xtdXv7a7
# padding : 44 for match_id : WdnWzvl9
# padding : 35 for match_id : jwuaxW7G
# padding : 41 for match_id : noKZVTpp
# padding : 47 for match_id : bqlOx0Jd
# padding : 42 for match_id : YTjLEmX6
# padding : 40 for match_id : p0jzzb3F
# padding : 43 for match_id : tKVkx71d
# padding : 47 for match_id : EZUVuzps
# padding : 46 for match_id : KzIBKszf
# padding : 51 for match_id : KYvoG7RA
# padding : 46 for match_id : Q56VAoca
# padding : 41 for match_id : SOFCZbAt
# padding : 46 for match_id : IeDfADON
# padding : 42 for match_id : Ysf0HUVj
# padding : 49 for match_id : dtoHREgb
# padding : 49 for match_id : CICb9XwU
# padding : 52 for match_id : fZXorSnF
# padding : 45 for match_id : lGs9TzPo
# padding : 42 for match_id : norrtE8i
# padding : 69 for match_id : zXqLQY84
# padding : 42 for match_id : QLxYNWhN
# padding : 46 for match_id : nB3Q4ino
# padding : 45 for match_id : 4CyxNj8T
# padding : 50 for match_id : WbwUOCwH
# padding : 42 for match_id : tI4h2b1s
# padding : 43 for match_id : Ee61LfQg
# padding : 40 for match_id : Ct1vojD7
# padding : 43 for match_id : vg6kTvgH
# padding : 41 for match_id : YeZonvs6
# padding : 43 for match_id : OzDnn8ZD
# padding : 45 for match_id : 8COX3w0N
# padding : 39 for match_id : zg3fHx5j
# padding : 40 for match_id : zRdaZHn2
# padding : 47 for match_id : UefapMGn
# padding : 42 for match_id : YBNnj01i
# padding : 43 for match_id : nRZK51pe
# padding : 43 for match_id : z1ou0NZ3
# padding : 50 for match_id : SzrX1q5i
# padding : 46 for match_id : f31tb14G
# padding : 39 for match_id : EipqaskA
# padding : 62 for match_id : jazSRlE7
# padding : 43 for match_id : QV3lw0Sj
# padding : 39 for match_id : fXtJTAqe
# padding : 66 for match_id : dIdwqGtM
# padding : 71 for match_id : Miry9YDk
# padding : 75 for match_id : jRnu8hTe
# padding : 67 for match_id : pQTVUFz9
# padding : 38 for match_id : ETkhRNNI
# padding : 35 for match_id : OMk7Hu8M
# padding : 34 for match_id : 2F5XXdgt
# padding : 38 for match_id : tA8y6Xjl
# padding : 43 for match_id : C2W8ZVuT
# padding : 34 for match_id : QgGf8Slb
# padding : 40 for match_id : SnO1fDwM
# padding : 34 for match_id : A7XCIMLt
# padding : 44 for match_id : Gnoc5Jd4
# padding : 38 for match_id : KnrFFHAN
# padding : 41 for match_id : h8Ulk17a
# padding : 36 for match_id : MLewQ8Nl
# padding : 39 for match_id : Sv6ZPg5b
# padding : 37 for match_id : 80hXDSf6
# padding : 40 for match_id : OGSMGLi4
# padding : 47 for match_id : tQjKz5K9
# padding : 41 for match_id : 6BfiGwwQ
# padding : 41 for match_id : AD2m2MxB
# padding : 46 for match_id : UHZDIsNi
# padding : 38 for match_id : xt6ZXZ6C
# padding : 41 for match_id : bXsqGr2n
# padding : 40 for match_id : zgFlpqeq
# padding : 40 for match_id : WxxlLGqC
# padding : 36 for match_id : Ui8DVpor
# padding : 36 for match_id : KErLV912
# padding : 43 for match_id : d8D73gkL
# padding : 35 for match_id : jZdPpjh9
# padding : 42 for match_id : zgcT6NOP
# padding : 37 for match_id : t4FYNSpd
# padding : 41 for match_id : I9lROvwr
# padding : 44 for match_id : vqLz0mdj
# padding : 42 for match_id : G4d7N2BB
# padding : 41 for match_id : UDemCtf6
# padding : 42 for match_id : Eu0LfhKA
# padding : 41 for match_id : zR6LReTt
# padding : 46 for match_id : dQInUKEb
# padding : 43 for match_id : WlCEhU4p
# padding : 42 for match_id : Wx8MNjlc
# padding : 47 for match_id : IXUMnHkp
# padding : 37 for match_id : K4LrsZkB
# padding : 54 for match_id : GlhYlfzS
# padding : 45 for match_id : bs1HscAB
# padding : 43 for match_id : vmm97anO
# padding : 41 for match_id : 0hO0hQ9G
# padding : 42 for match_id : QLbKLCGl
# padding : 46 for match_id : tpV3Z79E
# padding : 41 for match_id : xncez3Cb
# padding : 37 for match_id : vBgCWKBN
# padding : 40 for match_id : UmSrnq4s
# padding : 44 for match_id : h4Ivor2j
# padding : 46 for match_id : QkSkQ3W0
# padding : 44 for match_id : tWTHU7aJ
# padding : 34 for match_id : 0WEFpGef
# padding : 41 for match_id : l6r0Gm4S
# padding : 38 for match_id : riQ2A0zn
# padding : 39 for match_id : v7X0Yk0f
# padding : 38 for match_id : bebiyqch
# padding : 44 for match_id : AcQ5TfaE
# padding : 52 for match_id : MB8krnVT
# padding : 52 for match_id : vDYKp4A7
# padding : 41 for match_id : fLUeQPAH
# padding : 46 for match_id : pjcIsRuh
# padding : 45 for match_id : CtyCam04
# padding : 58 for match_id : OKfHw6wo
# padding : 39 for match_id : jRn319Vi
# padding : 48 for match_id : fqktnUV4
# padding : 43 for match_id : Ykx80Tpb
# padding : 45 for match_id : 29hlp80H
# padding : 55 for match_id : hGdMtoeb
# padding : 49 for match_id : veHzVyeD
# padding : 47 for match_id : bgymSot5
# padding : 39 for match_id : AFPJYJel
# padding : 45 for match_id : xpziR5eB
# padding : 45 for match_id : YBTaPqQN
# padding : 44 for match_id : 4fKVJNmo
# padding : 38 for match_id : EVpVvPPA
# padding : 44 for match_id : 4xPNXwBf
# padding : 51 for match_id : QkIjyDHn
# padding : 49 for match_id : rRSoxg2t
# padding : 48 for match_id : WOQFZatr
# padding : 53 for match_id : 86HdUJMh
# padding : 59 for match_id : K2Q1hoBR
# padding : 43 for match_id : I3kTK6kd
# padding : 62 for match_id : f7m6qMiG
# padding : 58 for match_id : rNOSi0ui
# padding : 75 for match_id : nqiAP00p
# padding : 67 for match_id : vcEsQXje
# padding : 57 for match_id : KzMkpqcO
# padding : 46 for match_id : tGNfr2Qp
# padding : 47 for match_id : reELNUqf
# padding : 67 for match_id : Gj72OXaO
# padding : 77 for match_id : Cd97bi2S
# padding : 70 for match_id : W6ZURhRj
# padding : 64 for match_id : Q3krhkud
# padding : 61 for match_id : vXb8uCej
# padding : 51 for match_id : YVua2Z23
# padding : 58 for match_id : KSFPmzlA
# padding : 77 for match_id : txHLlGY3
# padding : 63 for match_id : O0MGkdJc
# padding : 66 for match_id : 8l8xoYXS
# padding : 47 for match_id : INcCvWAd
# padding : 79 for match_id : pANCjx4i
# padding : 46 for match_id : EPVxEW1F
# padding : 47 for match_id : KSye3Fmc
# padding : 86 for match_id : 6qv70DXF
# padding : 64 for match_id : W0tYECn9
# padding : 58 for match_id : QaZtDjHL
# padding : 37 for match_id : Qq3MhJxq
# padding : 37 for match_id : bw1CJxTN
# padding : 35 for match_id : t2jHIdrU
# padding : 30 for match_id : xELyTgqG
# padding : 34 for match_id : SOyZ8Yip
# padding : 36 for match_id : CWVMh1pk
# padding : 35 for match_id : z5utFkZK
# padding : 33 for match_id : fkWWTZT9
# padding : 36 for match_id : rXJLWypi
# padding : 39 for match_id : KYjr0qhF
# padding : 37 for match_id : O6ZQiLae
# padding : 31 for match_id : GbXSUFE3
# padding : 35 for match_id : MNIPVeac
# padding : 35 for match_id : SbfjbNMR
# padding : 33 for match_id : U7tIgsVr
# Number of vectors after removing vectors with too much missing values : 0 over 2598
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 104
#     101 all_val_losses = []
#     102 all_last_indexes = []
# --> 104 for fold, (train_idx, val_idx) in enumerate(kf.split(dataset)):
#     105     tqdm.write(f"Fold {fold + 1}")
#     107     train_subset = Subset(dataset, train_idx)
#
# File ~/.local/lib/python3.9/site-packages/sklearn/model_selection/_split.py:370, in _BaseKFold.split(self, X, y, groups)
#     368 n_samples = _num_samples(X)
#     369 if self.n_splits > n_samples:
# --> 370     raise ValueError(
#     371         (
#     372             "Cannot have number of splits n_splits={0} greater"
#     373             " than the number of samples: n_samples={1}."
#     374         ).format(self.n_splits, n_samples)
#     375     )
#     377 for train, test in super().split(X, y, groups):
#     378     yield train, test
#
# ValueError: Cannot have number of splits n_splits=5 greater than the number of samples: n_samples=0.
